# %% [markdown]
# ### Library Imports

# %%
import os
import geopandas as gpd
import pandas as pd
import numpy as np
import random
from skimage import exposure
import matplotlib.pyplot as plt
import rasterio

from sklearn.metrics import classification_report, f1_score
from sklearn.preprocessing import StandardScaler, LabelEncoder, FunctionTransformer, OneHotEncoder, PowerTransformer
from sklearn.model_selection import StratifiedKFold, cross_val_predict, GridSearchCV, RandomizedSearchCV, train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.utils.class_weight import compute_class_weight
from sklearn.experimental import enable_iterative_imputer  # Required to enable IterativeImputer
from sklearn.impute import IterativeImputer, KNNImputer 
from sklearn.pipeline import Pipeline

from concurrent.futures import ThreadPoolExecutor, as_completed
from joblib import Parallel, delayed
import logging
from shapely import wkt
from shapely.geometry import Polygon, MultiPolygon
from shapely.affinity import scale, translate
import geemap
import ee
import shutil
import geemap
from tqdm import tqdm

from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from pytorch_tabnet.tab_model import TabNetClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# %% [markdown]
# ### Google Earth Engine Setup

# %%
# ee.Authenticate()
# ee.Initialize(project="my-project-1-398612")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# print(os.environ)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Loading and preparing data

# %%
file_path = r"C:\Users\USER\Downloads\Telangana_crop_health_challenge\Train.csv"
# Read the CSV file
train = pd.read_csv(file_path)

# Print the first 5 rows
train.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     FarmID  category   Crop      State District Sub-District       SDate  \
# 0  1326576   Healthy  Paddy  Telangana    Medak    Kulcharam  25-11-2023
# 1  1326577   Healthy  Paddy  Telangana    Medak    Kulcharam  13-11-2023
# 2  1326578   Healthy  Paddy  Telangana    Medak    Kulcharam  19-12-2023
# 3  1331836  Diseased  Paddy  Telangana    Medak    Kulcharam  11-02-2023
# 4  1326579  Diseased  Paddy  Telangana    Medak    Kulcharam  12-12-2023
#
#         HDate  CropCoveredArea  CHeight CNext   CLast        CTransp IrriType  \
# 0  14-04-2024               97       54   Pea  Lentil  Transplanting    Flood
# 1  26-04-2024               82       58   Pea  Lentil  Transplanting    Flood
# 2  28-04-2024               92       91   Pea  Lentil  Transplanting    Flood
# 3  04-11-2024               91       52   Pea  Lentil  Transplanting    Flood
# 4  19-05-2024               94       55   Pea  Lentil  Transplanting    Flood
#
#     IrriSource  IrriCount  WaterCov  ExpYield Season  \
# 0  Groundwater          4        87        17   Rabi
# 1        Canal          5        94        15   Rabi
# 2        Canal          3        99        20   Rabi
# 3        Canal          5        92        16   Rabi
# 4        Canal          5        97        20   Rabi
#
#                                             geometry
# 0  POLYGON ((78.18143246076087 17.978884603571068...
# 1  POLYGON ((78.17545177547453 17.981074445477304...
# 2  POLYGON ((78.16914224770792 17.976212849967755...
# 3  POLYGON ((78.16889103841902 17.974608186550842...
# 4  POLYGON ((78.17264452998072 17.969251496349454...

# %%
train.info()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8775 entries, 0 to 8774
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FarmID           8775 non-null   int64
#  1   category         8775 non-null   object
#  2   Crop             8775 non-null   object
#  3   State            8775 non-null   object
#  4   District         8775 non-null   object
#  5   Sub-District     8775 non-null   object
#  6   SDate            8775 non-null   object
#  7   HDate            8775 non-null   object
#  8   CropCoveredArea  8775 non-null   int64
#  9   CHeight          8775 non-null   int64
#  10  CNext            8775 non-null   object
#  11  CLast            8775 non-null   object
#  12  CTransp          8775 non-null   object
#  13  IrriType         8775 non-null   object
#  14  IrriSource       8775 non-null   object
#  15  IrriCount        8775 non-null   int64
#  16  WaterCov         8775 non-null   int64
#  17  ExpYield         8775 non-null   int64
#  18  Season           8775 non-null   object
#  19  geometry         8775 non-null   object
# dtypes: int64(6), object(14)
# memory usage: 1.3+ MB

# %%
file_path2 = r"C:\Users\USER\Downloads\Telangana_crop_health_challenge\Test.csv"
# Read the CSV file
test = pd.read_csv(file_path2)

# Print the first 5 rows
test.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     FarmID   Crop      State District Sub-District       SDate       HDate  \
# 0    85197  Paddy  Telangana    Medak     Nizampet  12-11-2023  14-05-2024
# 1   779677  Paddy  Telangana    Medak     Nizampet  20-12-2023  28-05-2024
# 2  1331840  Paddy  Telangana    Medak     Nizampet  29-11-2023  18-05-2024
# 3   483053  Paddy  Telangana    Medak     Nizampet  11-01-2023  27-04-2024
# 4   542945  Paddy  Telangana    Medak     Nizampet  11-04-2023  25-04-2024
#
#    CropCoveredArea  CHeight   CNext   CLast        CTransp IrriType  \
# 0               81       99  Lentil     Pea  Transplanting    Flood
# 1               91       63  Lentil     Pea  Transplanting    Flood
# 2               94       89     Pea  Lentil  Transplanting    Flood
# 3               83       78     Pea  Lentil  Transplanting    Flood
# 4               82       53  Lentil     Pea  Transplanting    Flood
#
#     IrriSource  IrriCount  WaterCov  ExpYield Season  \
# 0  Groundwater          5        81        19   Rabi
# 1        Canal          5        97        15   Rabi
# 2        Canal          5        88        15   Rabi
# 3        Canal          5        98        17   Rabi
# 4        Canal          6        98        18   Rabi
#
#                                             geometry
# 0  POLYGON ((78.54742059207287 18.062307326758276...
# 1  POLYGON ((78.54812514990353 18.06739449795583,...
# 2  POLYGON ((78.56002792938853 18.079607077817514...
# 3  POLYGON ((78.56216943364733 18.081207346902854...
# 4  POLYGON ((78.56844746870425 18.084730868444957...

# %%
test.info()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3016 entries, 0 to 3015
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FarmID           3016 non-null   int64
#  1   Crop             3016 non-null   object
#  2   State            3016 non-null   object
#  3   District         3016 non-null   object
#  4   Sub-District     3016 non-null   object
#  5   SDate            3016 non-null   object
#  6   HDate            3016 non-null   object
#  7   CropCoveredArea  3016 non-null   int64
#  8   CHeight          3016 non-null   int64
#  9   CNext            3016 non-null   object
#  10  CLast            3016 non-null   object
#  11  CTransp          3016 non-null   object
#  12  IrriType         3016 non-null   object
#  13  IrriSource       3016 non-null   object
#  14  IrriCount        3016 non-null   int64
#  15  WaterCov         3016 non-null   int64
#  16  ExpYield         3016 non-null   int64
#  17  Season           3016 non-null   object
#  18  geometry         3016 non-null   object
# dtypes: int64(6), object(13)
# memory usage: 447.8+ KB

# %% [markdown]
# ##### Convert Geometry Columns to Geospatial Format

# %%
# Convert WKT geometry to actual geometry objects
train['geometry'] = train['geometry'].apply(wkt.loads)
test['geometry'] = test['geometry'].apply(wkt.loads)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ##### Convert DataFrames to GeoDataFrames

# %%
# Convert to GeoDataFrames
train = gpd.GeoDataFrame(train, crs='epsg:4326')
test = gpd.GeoDataFrame(test, crs='epsg:4326')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ##### Concatenate Train and Test Data for Unified Processing

# %%
# Concatenate train and test datasets
data = pd.concat([train.assign(dataset='train'), test.assign(dataset='test')]).reset_index(drop=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
data.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     FarmID  category   Crop      State District Sub-District       SDate  \
# 0  1326576   Healthy  Paddy  Telangana    Medak    Kulcharam  25-11-2023
# 1  1326577   Healthy  Paddy  Telangana    Medak    Kulcharam  13-11-2023
# 2  1326578   Healthy  Paddy  Telangana    Medak    Kulcharam  19-12-2023
# 3  1331836  Diseased  Paddy  Telangana    Medak    Kulcharam  11-02-2023
# 4  1326579  Diseased  Paddy  Telangana    Medak    Kulcharam  12-12-2023
#
#         HDate  CropCoveredArea  CHeight  ...   CLast        CTransp IrriType  \
# 0  14-04-2024               97       54  ...  Lentil  Transplanting    Flood
# 1  26-04-2024               82       58  ...  Lentil  Transplanting    Flood
# 2  28-04-2024               92       91  ...  Lentil  Transplanting    Flood
# 3  04-11-2024               91       52  ...  Lentil  Transplanting    Flood
# 4  19-05-2024               94       55  ...  Lentil  Transplanting    Flood
#
#     IrriSource IrriCount  WaterCov  ExpYield  Season  \
# 0  Groundwater         4        87        17    Rabi
# 1        Canal         5        94        15    Rabi
# 2        Canal         3        99        20    Rabi
# 3        Canal         5        92        16    Rabi
# 4        Canal         5        97        20    Rabi
#
#                                             geometry dataset
# 0  POLYGON ((78.18143 17.97888, 78.18149 17.97899...   train
# 1  POLYGON ((78.17545 17.98107, 78.17578 17.98104...   train
# 2  POLYGON ((78.16914 17.97621, 78.1693 17.97619,...   train
# 3  POLYGON ((78.16889 17.97461, 78.16916 17.97471...   train
# 4  POLYGON ((78.17264 17.96925, 78.17276 17.96926...   train
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### Scale Geometry Object

# %%
# Function to scale each geometry around its centroid
def scale_geometry(geometry, scale_factor):
    """
    Scale a geometry object around its centroid.

    Parameters:
        geometry (shapely.geometry.base.BaseGeometry): Geometry to scale.
        scale_factor (float): Factor by which to scale the geometry.

    Returns:
        shapely.geometry.base.BaseGeometry: Scaled geometry object.
    """
    # Calculate centroid
    centroid = geometry.centroid
    # Translate geometry to origin
    translated_geometry = translate(geometry, -centroid.x, -centroid.y)
    # Scale geometry
    scaled_geometry = scale(translated_geometry, xfact=scale_factor, yfact=scale_factor, origin=(0, 0))
    # Translate back to the original centroid
    return translate(scaled_geometry, centroid.x, centroid.y)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Scale the geometries
scale_factor = 5
data['geometry'] = data['geometry'].apply(scale_geometry, scale_factor=scale_factor)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Download Image Data

# %% [markdown]
# ##### Utils

# %%
from datetime import datetime
import warnings

# Function to format date strings to 'YYYY-MM-DD'
def format_date(date_str):
    """
    Convert date string to 'YYYY-MM-DD' format, temporarily catching any warnings.

    Parameters:
        date_str (str): Date in string format.

    Returns:
        str: Formatted date string in 'YYYY-MM-DD' format, or None if invalid.
    """
    if date_str is None:
        return None

    try:
        with warnings.catch_warnings(record=True):
            warnings.simplefilter("always")
            # Attempt parsing in 'YYYY-MM-DD' format
            date = datetime.strptime(date_str, "%Y-%m-%d")
            return date.strftime("%Y-%m-%d")

    except ValueError:
        # Attempt parsing in 'DD/MM/YYYY' format
        try:
            date = datetime.strptime(date_str, "%d/%m/%Y")
            return date.strftime("%Y-%m-%d")
        
        # Attempt parsing in 'DD-MM-YYYY' format
        except ValueError:
            try:
                date = datetime.strptime(date_str, "%d-%m-%Y")
                return date.strftime("%Y-%m-%d")
            
            except ValueError:
                print(f"Unrecognized date format for {date_str}")
                return None

# Convert date strings to correct format
data['SDate'] = data['SDate'].apply(format_date)
data['HDate'] = data['HDate'].apply(format_date)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ##### Download from Earth Engine

# %%
# Define the `download` variable
download = False  # Set to True to download images, False to load existing data
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ##### Set Up Directories

# %%
# # Initialize Earth Engine
# ee.Initialize()

# # Remove existing 'downloads' folder if it exists
# if os.path.exists('downloads'):
#     os.system('rm -rf downloads')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Ensure the output directory exists
output_folder = 'downloads'
os.makedirs(output_folder, exist_ok=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Function to download RGB images from Earth Engine
def download_rgb_image(collection_name, bands, start_date, end_date, region, output_folder='downloads'):
    """Download RGB bands from a GEE collection filtered by date and region."""
    # Load the image collection, filter by date, and clip to region
    collection = ee.ImageCollection(collection_name).filterDate(start_date, end_date).filterBounds(region)
    image = collection.sort('system:time_start', False).first().select(bands).clip(region)  # Most recent image

    # Define unique filename based on image dates
    image_id = image.id().getInfo() or f'image_{start_date}_{end_date}'
    image_name = f'{output_folder}/{image_id}_RGB_{start_date}_{end_date}.tif'

    # Export the image to a GeoTIFF file
    geemap.ee_export_image(
        image,
        filename=image_name,
        scale=10,  # Sentinel-2 resolution in meters
        region=region,
        file_per_band=False,  # Save as a multi-band TIFF
        crs='EPSG:4326'
    )
    print(f"Downloaded: {image_name}")
    return image_name
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def process_row(index, row, image_collection_name, bands, output_folder):
    """
    Processes a row of data, downloads an image, and updates the DataFrame.

    Args:
        index (int): Index of the row in the DataFrame.
        row (pandas.Series): A row of data from the DataFrame.
        image_collection_name (str): Name of the Earth Engine image collection.
        bands (list[str]): List of bands to download from the image collection.
        output_folder (str): Path to the output folder for downloaded images.

    Returns:
        tuple: A tuple containing the index and downloaded image file path (or 'download_failed').
    """

    try:
        # Format date strings
        start_date = format_date(row['SDate'])
        end_date = format_date(row['HDate'])

        # Skip rows with invalid dates
        if not start_date or not end_date:
            print(f"Skipping entry due to invalid dates: SDate={row['SDate']}, HDate={row['HDate']}")
            return index, None

        # Extract and check geometry
        region_geometry = row['geometry']
        district = row['District']

        # Skip rows with empty or unsupported geometry types
        if region_geometry.is_empty:
            print(f"Skipping entry due to empty geometry for District: {district}")
            return index, None

        # Convert geometry to EE format
        if region_geometry.geom_type == 'Polygon':
            region = ee.Geometry.Polygon(region_geometry.__geo_interface__['coordinates'])
        elif region_geometry.geom_type == 'MultiPolygon':
            coords = [polygon.exterior.coords[:] for polygon in region_geometry.geoms]
            region = ee.Geometry.MultiPolygon(coords)
        else:
            print(f"Skipping unsupported geometry type: {region_geometry.geom_type} for District: {district}")
            return index, None
            
        # Download the image
        image_file = download_rgb_image(image_collection_name, bands, start_date, end_date, region, output_folder)

        if image_file:
            data.at[index, 'tif_path'] = image_file
            print(f"Downloaded image for row {index}: {image_file}")
            return index, image_file
        else:
            print(f"Failed to download image for row {index}")
            return index, None

    except Exception as e:
        print(f"Error processing row {index}: {e}")
        # Consider more specific error handling if needed
        data.at[index, 'tif_path'] = 'download_failed'
        return index, 'download_failed'
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
    # Define Sentinel-2 collection and bands
    image_collection_name = 'COPERNICUS/S2'
    bands = ['B4', 'B3', 'B2', 'B8', 'B5', 'B6', 'B7', 'B8A', 'B11', 'B12']
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
if download:
    with ThreadPoolExecutor(max_workers=4) as executor:
        futures = [
            executor.submit(process_row, index, row, image_collection_name, bands, output_folder)
            for index, row in data.iterrows()
        ]
        results = {future.result()[0]: future.result()[1] for future in as_completed(futures)}

    # Update the DataFrame with paths
    for idx, image_path in results.items():
        data.at[idx, 'tif_path'] = image_path

else:
    try:
        # Copy the downloads folder to the current directory if not already present
        if not os.path.exists('./downloads'):
            shutil.copytree(r'C:\Users\USER\Downloads\Telangana_crop_health_challenge\downloads', './downloads')
        
        # Set the data path explicitly
        data_path = r"C:\Users\USER\Downloads\telangana-crop-health-challenge\data.csv"
        
        # Load the existing data
        if os.path.exists(data_path):
            data = pd.read_csv(data_path)
            print("Data loaded successfully:")
            print(data.head())
        else:
            raise FileNotFoundError(f"The data file does not exist at {data_path}")
    except Exception as e:
        print(f"Error loading existing data: {e}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Data loaded successfully:
#     FarmID  category   Crop      State District Sub-District       SDate  \
# 0  1326576   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-11-25
# 1  1326577   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-11-13
# 2  1326578   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-12-19
# 3  1331836  Diseased  Paddy  Telangana    Medak    Kulcharam  2023-02-11
# 4  1326579  Diseased  Paddy  Telangana    Medak    Kulcharam  2023-12-12
#
#         HDate  CropCoveredArea  CHeight  ...        CTransp IrriType  \
# 0  2024-04-14               97       54  ...  Transplanting    Flood
# 1  2024-04-26               82       58  ...  Transplanting    Flood
# 2  2024-04-28               92       91  ...  Transplanting    Flood
# 3  2024-11-04               91       52  ...  Transplanting    Flood
# 4  2024-05-19               94       55  ...  Transplanting    Flood
#
#     IrriSource IrriCount WaterCov  ExpYield  Season  \
# 0  Groundwater         4       87        17    Rabi
# 1        Canal         5       94        15    Rabi
# 2        Canal         3       99        20    Rabi
# 3        Canal         5       92        16    Rabi
# 4        Canal         5       97        20    Rabi
#
#                                             geometry dataset  \
# 0  POLYGON ((78.18079255482755 17.978971746424413...   train
# 1  POLYGON ((78.17483419891283 17.981508840879556...   train
# 2  POLYGON ((78.16888476438905 17.976727511659835...   train
# 3  POLYGON ((78.16821795882959 17.974690113471414...   train
# 4  POLYGON ((78.17244459940454 17.969620948965225...   train
#
#                                             tif_path
# 0  downloads/20240412T050649_20240412T051727_T43Q...
# 1  downloads/20240425T051649_20240425T052817_T43Q...
# 2  downloads/20240427T050651_20240427T051439_T43Q...
# 3  downloads/20241103T050951_20241103T052004_T43Q...
# 4  downloads/20240517T050651_20240517T051655_T43Q...
#
# [5 rows x 22 columns]

# %%
# if download:
#     with ThreadPoolExecutor(max_workers=4) as executor:
#         futures = [
#             executor.submit(process_row, index, row, image_collection_name, bands, output_folder)
#             for index, row in data.iterrows()
#         ]
#         results = {future.result()[0]: future.result()[1] for future in as_completed(futures)}

#     # Update the DataFrame with paths
#     for idx, image_path in results.items():
#         data.at[idx, 'tif_path'] = image_path

# else:
#     try:
#         shutil.copytree('/Users/USER/Downloads/Telangana_crop_health_challenge/downloads', '.')
#         data_path = 'data.csv'
#         data = pd.read_csv(data_path)
#     except Exception as e:
#         print(f"Error loading existing data: {e}")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
data.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     FarmID  category   Crop      State District Sub-District       SDate  \
# 0  1326576   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-11-25
# 1  1326577   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-11-13
# 2  1326578   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-12-19
# 3  1331836  Diseased  Paddy  Telangana    Medak    Kulcharam  2023-02-11
# 4  1326579  Diseased  Paddy  Telangana    Medak    Kulcharam  2023-12-12
#
#         HDate  CropCoveredArea  CHeight  ...        CTransp IrriType  \
# 0  2024-04-14               97       54  ...  Transplanting    Flood
# 1  2024-04-26               82       58  ...  Transplanting    Flood
# 2  2024-04-28               92       91  ...  Transplanting    Flood
# 3  2024-11-04               91       52  ...  Transplanting    Flood
# 4  2024-05-19               94       55  ...  Transplanting    Flood
#
#     IrriSource IrriCount WaterCov  ExpYield  Season  \
# 0  Groundwater         4       87        17    Rabi
# 1        Canal         5       94        15    Rabi
# 2        Canal         3       99        20    Rabi
# 3        Canal         5       92        16    Rabi
# 4        Canal         5       97        20    Rabi
#
#                                             geometry dataset  \
# 0  POLYGON ((78.18079255482755 17.978971746424413...   train
# 1  POLYGON ((78.17483419891283 17.981508840879556...   train
# 2  POLYGON ((78.16888476438905 17.976727511659835...   train
# 3  POLYGON ((78.16821795882959 17.974690113471414...   train
# 4  POLYGON ((78.17244459940454 17.969620948965225...   train
#
#                                             tif_path
# 0  downloads/20240412T050649_20240412T051727_T43Q...
# 1  downloads/20240425T051649_20240425T052817_T43Q...
# 2  downloads/20240427T050651_20240427T051439_T43Q...
# 3  downloads/20241103T050951_20241103T052004_T43Q...
# 4  downloads/20240517T050651_20240517T051655_T43Q...
#
# [5 rows x 22 columns]

# %%
data.tail()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#         FarmID category   Crop      State District Sub-District       SDate  \
# 11786   551119      NaN  Maize  Telangana   Nirmal   Sarangapur  2023-10-12
# 11787   916476      NaN  Maize  Telangana   Nirmal   Sarangapur  2023-05-11
# 11788   121860      NaN  Maize  Telangana   Nirmal   Sarangapur  2023-11-14
# 11789   270936      NaN  Maize  Telangana   Nirmal   Sarangapur  2023-02-12
# 11790  1326552      NaN  Maize  Telangana   Nirmal   Sarangapur  2023-11-23
#
#             HDate  CropCoveredArea  CHeight  ...        CTransp   IrriType  \
# 11786  2024-07-03               92      225  ...       Drilling       Drip
# 11787  2024-04-03               79      236  ...  Seed Drilling       Drip
# 11788  2024-03-04               87      210  ...   Broadcasting  Sprinkler
# 11789  2024-03-26               95      204  ...       Drilling  Sprinkler
# 11790  2024-03-22               78      185  ...   Broadcasting       Drip
#
#         IrriSource IrriCount WaterCov  ExpYield  Season  \
# 11786  Groundwater         4       44        39    Rabi
# 11787        Canal         3       41        40    Rabi
# 11788        Canal         3       43        41    Rabi
# 11789        Canal         4       48        39    Rabi
# 11790        Canal         2       52        41    Rabi
#
#                                                 geometry dataset  \
# 11786  POLYGON ((78.25900010978795 19.22927351046702,...    test
# 11787  POLYGON ((78.25818808460964 19.202014687110104...    test
# 11788  POLYGON ((78.2554603258883 19.19636630652319, ...    test
# 11789  POLYGON ((78.25742756428231 19.195573453548704...    test
# 11790  POLYGON ((78.26473996074711 19.225096392031386...    test
#
#                                                 tif_path
# 11786  downloads/20240701T050659_20240701T051520_T43Q...
# 11787  downloads/20240402T050649_20240402T051718_T43Q...
# 11788  downloads/20240303T050719_20240303T051936_T43Q...
# 11789  downloads/20240323T050649_20240323T051727_T43Q...
# 11790  downloads/20240321T051651_20240321T053116_T43Q...
#
# [5 rows x 22 columns]

# %%
data.info()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11791 entries, 0 to 11790
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FarmID           11791 non-null  int64
#  1   category         8775 non-null   object
#  2   Crop             11791 non-null  object
#  3   State            11791 non-null  object
#  4   District         11791 non-null  object
#  5   Sub-District     11791 non-null  object
#  6   SDate            11791 non-null  object
#  7   HDate            11791 non-null  object
#  8   CropCoveredArea  11791 non-null  int64
#  9   CHeight          11791 non-null  int64
#  10  CNext            11791 non-null  object
#  11  CLast            11791 non-null  object
#  12  CTransp          11791 non-null  object
#  13  IrriType         11791 non-null  object
#  14  IrriSource       11791 non-null  object
#  15  IrriCount        11791 non-null  int64
#  16  WaterCov         11791 non-null  int64
#  17  ExpYield         11791 non-null  int64
#  18  Season           11791 non-null  object
#  19  geometry         11791 non-null  object
#  20  dataset          11791 non-null  object
#  21  tif_path         11791 non-null  object
# dtypes: int64(6), object(16)
# memory usage: 2.0+ MB

# %% [markdown]
# #### Visualisation

# %%
# Function to scale pixel values to the 0–255 range for better visualization
def scale_band(band):
    """
    Scales pixel values of a single band to the 0-255 range.

    Parameters:
    - band: np.array, pixel values of the band

    Returns:
    - np.array, scaled pixel values in the 0-255 range
    """
    band = band.astype(np.float32)  # Ensure values are in float for scaling
    return 255 * (band - np.min(band)) / (np.max(band) - np.min(band))  # Scale to 0–255

# Function to visualize RGB image with scaling, contrast adjustments, and optional gamma correction
def visualize_rgb_image(file_path, gamma=0.6, contrast_stretch=True):
    """
    Visualize an RGB image using matplotlib with scaling, optional gamma correction, and contrast stretching.

    Parameters:
    - file_path: str, path to the RGB image file (GeoTIFF)
    - gamma: float, gamma correction factor (default=0.6)
    - contrast_stretch: bool, whether to apply contrast stretching (default=True)
    """
    # Open the image file
    with rasterio.open(file_path) as src:
        # Read RGB bands (assuming Sentinel-2 band order: Red=B4, Green=B3, Blue=B2)
        red = src.read(3)  # Band 4 for Red
        green = src.read(2)  # Band 3 for Green
        blue = src.read(1)  # Band 2 for Blue

        # Scale each band to the 0–255 range for better visualization
        red_scaled = scale_band(red)
        green_scaled = scale_band(green)
        blue_scaled = scale_band(blue)

        # Stack the scaled RGB bands into a single image
        rgb = np.dstack((red_scaled, green_scaled, blue_scaled)).astype(np.uint8)

        # Apply contrast stretching if specified
        if contrast_stretch:
            p2, p98 = np.percentile(rgb, (2, 98))  # Calculate 2nd and 98th percentiles for stretching
            rgb = exposure.rescale_intensity(rgb, in_range=(p2, p98))

        # Apply gamma correction to adjust brightness
        rgb = exposure.adjust_gamma(rgb, gamma=gamma)

        # Display the processed image using matplotlib
        plt.figure(figsize=(5, 5))
        plt.imshow(rgb)
        plt.axis('off')  # Hide axes for a cleaner look
        plt.title("RGB Composite (Red-Green-Blue) with Scaling, Contrast Stretch, and Gamma Correction")
        plt.show()

    return rgb
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Select a random image file from the dataset and visualize it
path = random.choice(data['tif_path'].values)
image = visualize_rgb_image(path)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# #### Feature Engineering

# %%
# Example feature calculation functions
def calculate_ndvi(nir_band, red_band):
    """Calculate NDVI (Normalized Difference Vegetation Index)."""
    ndvi = (nir_band - red_band) / (nir_band + red_band)
    return np.nanmean(ndvi)

def calculate_evi(nir_band, red_band, blue_band):
    """Calculate EVI (Enhanced Vegetation Index)."""
    evi = 2.5 * (nir_band - red_band) / (nir_band + 6 * red_band - 7.5 * blue_band + 1)
    return np.nanmean(evi)

def calculate_ndwi(nir_band, green_band):
    """Calculate NDWI (Normalized Difference Water Index)."""
    ndwi = (green_band - nir_band) / (green_band + nir_band)
    return np.nanmean(ndwi)

def calculate_gndvi(nir_band, green_band):
    """Calculate GNDVI (Green Normalized Difference Vegetation Index)."""
    gndvi = (nir_band - green_band) / (nir_band + green_band)
    return np.nanmean(gndvi)

def calculate_savi(nir_band, red_band, L=0.5):
    """Calculate SAVI (Soil Adjusted Vegetation Index)."""
    savi = ((nir_band - red_band) / (nir_band + red_band + L)) * (1 + L)
    return np.nanmean(savi)

def calculate_msavi(nir_band, red_band):
    """Calculate MSAVI (Modified Soil Adjusted Vegetation Index)."""
    msavi = (2 * nir_band + 1 - np.sqrt((2 * nir_band + 1)**2 - 8 * (nir_band - red_band))) / 2
    return np.nanmean(msavi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Function to calculate features for each row in the data
def process_row_for_features(index, row):
    features = {'index': index}

    # Retrieve the TIFF file path and check if it's valid
    tif_path = row['tif_path']
    if not isinstance(tif_path, str) or not os.path.exists(tif_path):
        print(f"Skipping entry due to missing or invalid tif_path for index {index}")
        # Add NaN for all features if path is invalid
        features.update({
            'ndvi': np.nan,
            'evi': np.nan,
            'ndwi': np.nan,
            'gndvi': np.nan,
            'savi': np.nan,
            'msavi': np.nan
        })
        return features

    # Open the TIFF file and read bands for feature calculation
    try:
        with rasterio.open(tif_path) as src:
            red = src.read(3)    # B4 for Red
            green = src.read(2)  # B3 for Green
            blue = src.read(1)   # B2 for Blue
            nir = src.read(4)    # B8 for NIR

            # Calculate each feature
            features['ndvi'] = calculate_ndvi(nir, red)
            features['evi'] = calculate_evi(nir, red, blue)
            features['ndwi'] = calculate_ndwi(nir, green)
            features['gndvi'] = calculate_gndvi(nir, green)
            features['savi'] = calculate_savi(nir, red)
            features['msavi'] = calculate_msavi(nir, red)

    except Exception as e:
        print(f"Error processing {tif_path} for index {index}: {e}")
        features.update({
            'ndvi': np.nan,
            'evi': np.nan,
            'ndwi': np.nan,
            'gndvi': np.nan,
            'savi': np.nan,
            'msavi': np.nan
        })
    return features
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Calculate features in parallel, controlling progress bar behavior
new_features = Parallel(n_jobs=-1)(delayed(process_row_for_features)(index, row)
                                   for index, row in tqdm(data.iterrows(), total=len(data), position=0, leave=True))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 100%|████████████████████████████████████████████████████████████████████████████| 11791/11791 [03:45<00:00, 52.24it/s]

# %%
# Merge new features with the data
new_features_df = pd.DataFrame(new_features).set_index('index')
data = data.join(new_features_df)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
data.head()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     FarmID  category   Crop      State District Sub-District       SDate  \
# 0  1326576   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-11-25
# 1  1326577   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-11-13
# 2  1326578   Healthy  Paddy  Telangana    Medak    Kulcharam  2023-12-19
# 3  1331836  Diseased  Paddy  Telangana    Medak    Kulcharam  2023-02-11
# 4  1326579  Diseased  Paddy  Telangana    Medak    Kulcharam  2023-12-12
#
#         HDate  CropCoveredArea  CHeight  ... Season  \
# 0  2024-04-14               97       54  ...   Rabi
# 1  2024-04-26               82       58  ...   Rabi
# 2  2024-04-28               92       91  ...   Rabi
# 3  2024-11-04               91       52  ...   Rabi
# 4  2024-05-19               94       55  ...   Rabi
#
#                                             geometry dataset  \
# 0  POLYGON ((78.18079255482755 17.978971746424413...   train
# 1  POLYGON ((78.17483419891283 17.981508840879556...   train
# 2  POLYGON ((78.16888476438905 17.976727511659835...   train
# 3  POLYGON ((78.16821795882959 17.974690113471414...   train
# 4  POLYGON ((78.17244459940454 17.969620948965225...   train
#
#                                             tif_path      ndvi       evi  \
# 0  downloads/20240412T050649_20240412T051727_T43Q...  0.100756 -0.793684
# 1  downloads/20240425T051649_20240425T052817_T43Q...  0.188090  0.564248
# 2  downloads/20240427T050651_20240427T051439_T43Q...  0.206596 -1.456745
# 3  downloads/20241103T050951_20241103T052004_T43Q...  0.206250  2.206184
# 4  downloads/20240517T050651_20240517T051655_T43Q...  0.179721 -0.743638
#
#         ndwi     gndvi      savi        msavi
# 0   8.488031  0.127153  0.151125  4232.596191
# 1  11.493762  0.187815  0.282110  3249.392822
# 2  10.166884  0.206553  0.309869  3741.956055
# 3  10.446196  0.220995  0.309350  3673.396729
# 4   8.665929  0.160657  0.269563  4227.338379
#
# [5 rows x 28 columns]

# %%
data.info()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11791 entries, 0 to 11790
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FarmID           11791 non-null  int64
#  1   category         8775 non-null   object
#  2   Crop             11791 non-null  object
#  3   State            11791 non-null  object
#  4   District         11791 non-null  object
#  5   Sub-District     11791 non-null  object
#  6   SDate            11791 non-null  object
#  7   HDate            11791 non-null  object
#  8   CropCoveredArea  11791 non-null  int64
#  9   CHeight          11791 non-null  int64
#  10  CNext            11791 non-null  object
#  11  CLast            11791 non-null  object
#  12  CTransp          11791 non-null  object
#  13  IrriType         11791 non-null  object
#  14  IrriSource       11791 non-null  object
#  15  IrriCount        11791 non-null  int64
#  16  WaterCov         11791 non-null  int64
#  17  ExpYield         11791 non-null  int64
#  18  Season           11791 non-null  object
#  19  geometry         11791 non-null  object
#  20  dataset          11791 non-null  object
#  21  tif_path         11791 non-null  object
#  22  ndvi             10584 non-null  float64
#  23  evi              10595 non-null  float64
#  24  ndwi             10584 non-null  float64
#  25  gndvi            10584 non-null  float64
#  26  savi             10595 non-null  float64
#  27  msavi            10595 non-null  float64
# dtypes: float64(6), int64(6), object(16)
# memory usage: 2.5+ MB

# %%
unique_counts = data['tif_path'].value_counts()
print(unique_counts)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# tif_path
# download_failed                                                                   1196
# downloads/20240522T050649_20240522T051545_T43QHA_RGB_2023-08-11_2024-05-25.tif       4
# downloads/20231025T050859_20231025T051705_T44QLE_RGB_2023-06-17_2023-10-26.tif       3
# downloads/20240415T051649_20240415T053023_T43QHB_RGB_2023-11-14_2024-04-16.tif       3
# downloads/20231229T051221_20231229T052219_T43QHB_RGB_2023-07-22_2023-12-31.tif       3
#                                                                                   ...
# downloads/20241101T051859_20241101T052722_T43QHB_RGB_2023-11-18_2024-11-04.tif       1
# downloads/20240301T051741_20240301T053320_T43QHB_RGB_2023-11-29_2024-03-04.tif       1
# downloads/20240321T051651_20240321T053116_T43QHB_RGB_2023-11-29_2024-03-25.tif       1
# downloads/20240321T051651_20240321T053116_T43QHB_RGB_2023-11-12_2024-03-26.tif       1
# downloads/20240321T051651_20240321T053116_T43QHB_RGB_2023-11-23_2024-03-22.tif       1
# Name: count, Length: 10037, dtype: int64

# %%
# Get unique values for each column
unique_values = {col: data[col].unique() for col in data.columns}

# Display the unique values count for each column
unique_counts = {col: data[col].nunique() for col in data.columns}

# Print the unique values and their counts
for col in data.columns:
    print(f"Feature: {col}")
    print(f"Unique Values ({unique_counts[col]}): {unique_values[col]}")
    print("-" * 50)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Feature: FarmID
# Unique Values (11791): [1326576 1326577 1326578 ...  121860  270936 1326552]
# --------------------------------------------------
# Feature: category
# Unique Values (4): ['Healthy' 'Diseased' 'Pests' 'Stressed' nan]
# --------------------------------------------------
# Feature: Crop
# Unique Values (7): ['Paddy' 'Cotton' 'Maize' 'Bengal Gram' 'Groundnut' 'Chillies' 'Red Gram']
# --------------------------------------------------
# Feature: State
# Unique Values (1): ['Telangana']
# --------------------------------------------------
# Feature: District
# Unique Values (16): ['Medak' 'Siddipet' 'Adilabad' 'Nirmal' 'Mahabubnagar' 'Nagarkurnool'
#  'Narayanpet' 'Vikarabad' 'Wanaparthy' 'Nalgonda' 'Kamareddy'
#  'Mahabubabad' 'Khammam' 'Warangal' 'Sangareddy' 'Kumurambheem Asifabad']
# --------------------------------------------------
# Feature: Sub-District
# Unique Values (151): ['Kulcharam' 'Kowdipally' 'Chilipched' 'Narsapur' 'Yeldurthy' 'Medak'
#  'Chegunta' 'Doultabad' 'Ramayampet' 'Shankarampet_A' 'Manoharabad'
#  'Alladurg' 'Havelighanpur' 'Inderavelly' 'Sirikonda' 'Ichoda'
#  'Neradigonda' 'Sonala' 'Bazarhathnoor' 'Gudihathnur' 'Utnur' 'Gadiguda'
#  'Bela' 'Jainad' 'Bhoraj' 'Bheempoor' 'Tamsi' 'Adilabad Rural' 'Pembi'
#  'Boath' 'Rajapur' 'Balanagar' 'Midjil' 'Urkonda' 'Bhoothpur' 'Hanwada'
#  'Koilkonda' 'Kothapalle' 'Mohammadabad' 'Nawabpet' 'Kulkacharla' 'Doma'
#  'Kosgi' 'Koukuntla' 'Chinna Chinta Kunta' 'Amarchintha' 'Bhainsa'
#  'Kubeer' 'Beltaroda' 'Basar' 'Tanoor' 'Mudhole' 'Lokeshwaram'
#  'Laxmanchanda' 'Mamda' 'Kanagal' 'Nalgonda' 'Kattangur' 'Shaligouraram'
#  'Ammanabole' 'Narketpally' 'Madugulapally' 'Tripuraram' 'Nidamanoor'
#  'Anumula_Haliya' 'Tirumalagiri_Sagar' 'Peda Adisharla Palli'
#  'Kondamallapally' 'Chinthapally' 'Chandur' 'Tipparthy' 'Peddavoora'
#  'Chityal' 'Gudipalli' 'Gurrampode' 'Devarakonda' 'Chandampet' 'Gattuppal'
#  'Mahabubnagar_Urban' 'Shivampet' 'Bhiknoor' 'Narsingi' 'Shankarampet_R'
#  'Bayyaram' 'Garla' 'Singareni' 'Kuravi' 'Seerole' 'Dornakal' 'Nellikudur'
#  'Thorrur' 'Narsimhulapet' 'Nekkonda' 'Gudur' 'Chennaraopet' 'Khanapur'
#  'Kothaguda' 'Narsapur_G' 'Beeravelli' 'Soan' 'Dilawarpur' 'Damaracherla'
#  'Devarkadra' 'Mavala' 'Damargidda' 'Akbarpet-bhoompally' 'Inugurthy'
#  'Narayanpet' 'Masaipet' 'Mahabubnagar_Rural' 'Vemulapally' 'Miryalaguda'
#  'Gangaram' 'Peddavangara' 'Maripeda' 'Khammam_Rural' 'Nizampet' 'Tekmal'
#  'Toopran' 'Vatpally' 'Jainoor' 'Narnoor' 'Talamadugu' 'Sathnala'
#  'Gandeed' 'Jadcherla' 'Addakal' 'Malegaon' 'Ponkal' 'Nampally'
#  'Kethepally' 'Nakrekal' 'Gundlapally' 'Munugode' 'Neredugommu'
#  'Marriguda' 'Kuntala' 'Bibipet' 'Mahabubabad' 'Kesamudram' 'Sarangapur'
#  'Nirmal Rural' 'Adavidevulapally' 'Gundmal' 'Adilabad Urban' 'Kerameri'
#  'Maddur' 'Doulthabad' 'Papannapet' 'Parvathagiri' 'Chinnagudur']
# --------------------------------------------------
# Feature: SDate
# Unique Values (576): ['2023-11-25' '2023-11-13' '2023-12-19' '2023-02-11' '2023-12-12'
#  '2023-12-13' '2023-11-20' '2023-12-14' '2023-10-12' '2023-02-12'
#  '2023-06-12' '2023-12-28' '2023-09-11' '2023-12-24' '2023-12-20'
#  '2023-12-18' '2023-12-11' '2023-01-11' '2023-12-23' '2023-11-11'
#  '2023-04-12' '2023-11-21' '2023-12-27' '2023-09-12' '2023-03-12'
#  '2023-11-19' '2023-11-24' '2023-07-11' '2023-12-22' '2023-11-27'
#  '2023-11-15' '2023-05-12' '2023-10-11' '2023-12-25' '2023-11-29'
#  '2023-11-17' '2023-12-30' '2023-11-12' '2023-08-12' '2023-11-22'
#  '2023-08-11' '2023-12-21' '2023-11-23' '2023-05-11' '2023-07-12'
#  '2023-12-29' '2023-11-26' '2023-11-18' '2023-01-12' '2023-12-16'
#  '2023-10-30' '2023-10-21' '2023-10-22' '2023-10-16' '2023-10-29'
#  '2023-05-10' '2023-03-10' '2023-12-10' '2023-06-10' '2023-09-10'
#  '2023-10-28' '2023-10-27' '2023-10-25' '2023-12-15' '2023-03-11'
#  '2023-04-11' '2023-10-23' '2023-10-19' '2023-11-14' '2023-10-14'
#  '2023-10-31' '2023-11-16' '2023-10-10' '2023-10-18' '2023-12-17'
#  '2023-02-10' '2023-10-15' '2023-10-20' '2023-06-11' '2023-01-10'
#  '2023-08-10' '2023-11-30' '2023-10-26' '2023-10-24' '2023-07-10'
#  '2023-12-26' '2023-10-17' '2023-11-28' '2023-11-10' '2023-04-10'
#  '2023-10-13' '2023-10-07' '2023-11-01' '2023-11-06' '2023-11-04'
#  '2023-10-06' '2023-11-08' '2023-10-05' '2023-11-03' '2023-11-07'
#  '2023-11-05' '2023-10-03' '2023-10-02' '2023-11-09' '2023-10-09'
#  '2023-10-04' '2023-10-01' '2023-11-02' '2023-10-08' '2024-09-05'
#  '2023-06-26' '2023-07-22' '2024-05-12' '2023-05-30' '2023-04-21'
#  '2024-04-20' '2023-02-04' '2024-09-28' '2023-09-09' '2023-04-24'
#  '2023-01-28' '2024-08-16' '2024-07-19' '2024-07-09' '2023-05-06'
#  '2023-03-21' '2024-02-07' '2024-01-28' '2024-09-21' '2024-05-25'
#  '2024-03-24' '2024-05-18' '2024-05-29' '2024-04-15' '2024-08-21'
#  '2024-01-25' '2024-01-23' '2023-02-21' '2024-04-17' '2024-09-13'
#  '2023-02-22' '2023-03-16' '2024-08-03' '2024-07-15' '2023-04-17'
#  '2023-06-24' '2023-04-06' '2024-03-01' '2023-02-25' '2024-08-27'
#  '2023-07-08' '2024-08-19' '2024-08-31' '2023-03-31' '2023-03-17'
#  '2024-08-09' '2024-05-16' '2024-06-30' '2024-04-22' '2023-04-15'
#  '2024-09-24' '2024-06-04' '2024-07-23' '2023-03-25' '2024-03-18'
#  '2024-06-21' '2024-09-06' '2023-08-26' '2024-06-16' '2023-04-25'
#  '2024-05-05' '2024-08-26' '2024-09-15' '2023-04-08' '2024-01-01'
#  '2023-09-22' '2024-10-01' '2023-08-14' '2024-03-13' '2024-04-29'
#  '2024-09-01' '2024-05-30' '2024-06-22' '2024-08-06' '2024-02-10'
#  '2024-08-13' '2024-09-09' '2024-02-20' '2023-08-07' '2024-03-31'
#  '2023-09-05' '2023-04-27' '2023-12-01' '2023-07-14' '2024-06-10'
#  '2024-03-04' '2023-08-19' '2024-07-14' '2024-04-04' '2023-12-31'
#  '2024-04-07' '2024-03-09' '2024-03-19' '2024-09-19' '2023-02-08'
#  '2023-05-27' '2024-08-04' '2024-09-03' '2024-07-08' '2023-08-27'
#  '2023-03-06' '2024-04-13' '2024-05-14' '2024-09-08' '2023-02-28'
#  '2023-06-21' '2024-02-17' '2024-08-02' '2024-07-10' '2023-04-30'
#  '2024-04-10' '2024-03-03' '2023-03-26' '2023-04-05' '2024-02-15'
#  '2023-06-27' '2024-06-12' '2023-08-24' '2024-06-08' '2024-06-28'
#  '2024-06-19' '2023-07-24' '2023-12-03' '2023-06-13' '2024-09-20'
#  '2024-03-07' '2023-06-06' '2023-06-28' '2024-09-25' '2024-07-21'
#  '2024-01-18' '2023-08-22' '2023-03-14' '2023-06-30' '2023-01-08'
#  '2024-03-06' '2024-01-20' '2023-05-13' '2024-05-26' '2024-09-17'
#  '2023-02-14' '2024-06-27' '2024-01-27' '2023-08-23' '2024-04-09'
#  '2024-07-13' '2024-04-28' '2024-04-27' '2024-06-20' '2023-09-26'
#  '2024-07-27' '2023-01-09' '2024-08-25' '2024-09-27' '2023-08-13'
#  '2023-03-02' '2024-02-25' '2023-01-13' '2023-08-09' '2024-05-03'
#  '2024-02-21' '2024-01-07' '2024-05-17' '2024-05-09' '2023-02-13'
#  '2023-05-20' '2023-04-28' '2023-02-18' '2024-02-28' '2023-09-29'
#  '2024-01-11' '2023-08-08' '2023-06-02' '2023-03-08' '2023-08-02'
#  '2023-03-05' '2024-09-02' '2024-06-01' '2023-05-16' '2023-05-28'
#  '2024-02-23' '2023-01-17' '2024-04-23' '2023-06-14' '2023-07-01'
#  '2024-04-18' '2023-08-16' '2024-04-30' '2023-07-19' '2023-08-28'
#  '2024-01-09' '2023-01-27' '2024-05-15' '2024-08-11' '2024-08-23'
#  '2024-04-25' '2024-08-28' '2023-07-25' '2023-04-16' '2024-01-05'
#  '2023-05-14' '2024-06-06' '2023-02-27' '2023-05-15' '2024-05-24'
#  '2023-04-22' '2023-01-15' '2023-01-18' '2023-02-17' '2024-02-11'
#  '2023-07-20' '2024-04-24' '2023-04-01' '2023-07-18' '2024-06-24'
#  '2023-01-14' '2023-05-02' '2024-07-25' '2024-01-31' '2024-04-19'
#  '2023-07-17' '2024-02-14' '2023-07-05' '2023-12-05' '2023-08-05'
#  '2023-09-15' '2023-08-30' '2024-02-04' '2023-09-19' '2024-09-30'
#  '2023-05-04' '2024-01-10' '2024-07-07' '2023-07-29' '2024-07-22'
#  '2023-07-06' '2023-07-16' '2024-02-02' '2024-05-21' '2023-04-26'
#  '2024-09-11' '2024-08-22' '2023-05-21' '2023-04-14' '2023-01-31'
#  '2023-07-02' '2024-09-18' '2024-01-04' '2024-02-13' '2023-09-01'
#  '2024-07-03' '2023-06-07' '2023-03-28' '2023-09-21' '2024-04-11'
#  '2024-02-19' '2023-01-25' '2023-09-27' '2024-08-10' '2024-07-29'
#  '2023-12-06' '2023-03-19' '2023-05-29' '2024-04-16' '2023-05-19'
#  '2023-01-07' '2024-06-25' '2024-02-08' '2023-04-03' '2024-04-14'
#  '2023-08-31' '2023-12-04' '2023-12-07' '2023-08-03' '2024-06-11'
#  '2024-08-14' '2024-05-11' '2023-07-09' '2023-08-01' '2024-04-21'
#  '2023-07-21' '2023-06-20' '2023-07-15' '2023-02-07' '2023-07-27'
#  '2023-06-16' '2023-07-30' '2023-03-07' '2023-04-07' '2023-06-23'
#  '2023-01-06' '2023-07-23' '2023-06-17' '2023-07-07' '2023-06-18'
#  '2023-09-07' '2023-06-15' '2023-06-22' '2023-09-06' '2023-02-06'
#  '2023-06-19' '2023-05-07' '2023-06-29' '2023-07-26' '2023-07-28'
#  '2023-07-13' '2023-06-25' '2023-01-05' '2023-08-06' '2023-05-24'
#  '2023-05-05' '2023-06-05' '2023-05-31' '2023-02-05' '2023-05-23'
#  '2023-05-18' '2023-05-26' '2023-05-25' '2023-05-22' '2023-06-08'
#  '2023-05-03' '2023-06-01' '2023-05-09' '2023-05-08' '2023-06-09'
#  '2023-06-03' '2023-06-04' '2023-05-01' '2023-05-17' '2023-09-16'
#  '2024-02-06' '2024-01-16' '2023-04-29' '2024-06-23' '2023-08-21'
#  '2024-06-26' '2024-07-11' '2023-09-03' '2023-03-13' '2024-09-10'
#  '2024-05-27' '2024-01-24' '2024-02-26' '2023-01-21' '2024-03-12'
#  '2023-08-15' '2023-12-02' '2024-08-08' '2024-05-10' '2023-04-19'
#  '2023-07-04' '2024-02-05' '2023-01-19' '2024-01-08' '2024-06-03'
#  '2024-05-22' '2024-07-16' '2023-08-04' '2024-07-12' '2024-02-16'
#  '2024-08-17' '2024-09-12' '2023-08-29' '2023-01-30' '2024-05-08'
#  '2023-02-15' '2023-02-09' '2023-07-03' '2024-02-09' '2024-07-02'
#  '2024-02-12' '2023-01-16' '2023-09-25' '2024-03-28' '2024-01-17'
#  '2024-05-04' '2024-09-14' '2023-09-30' '2024-07-30' '2023-09-04'
#  '2023-09-13' '2024-05-23' '2023-04-18' '2024-01-06' '2023-03-29'
#  '2024-01-02' '2024-03-26' '2024-08-01' '2023-02-01' '2024-03-29'
#  '2024-02-03' '2024-05-13' '2023-03-18' '2024-06-14' '2024-07-05'
#  '2024-09-22' '2024-07-26' '2024-02-18' '2024-03-02' '2024-04-05'
#  '2023-08-17' '2023-04-13' '2024-02-27' '2024-01-13' '2024-02-01'
#  '2024-02-24' '2024-06-05' '2024-05-28' '2023-04-04' '2024-03-25'
#  '2024-05-07' '2023-09-02' '2024-01-19' '2024-03-27' '2023-03-15'
#  '2023-04-20' '2024-08-05' '2023-09-14' '2023-01-26' '2024-09-04'
#  '2023-09-24' '2024-04-01' '2024-05-06' '2023-02-24' '2023-03-23'
#  '2024-01-12' '2024-09-23' '2024-09-16' '2023-02-23' '2024-03-21'
#  '2024-09-07' '2024-04-03' '2024-07-18' '2024-03-14' '2023-09-17'
#  '2023-02-26' '2024-03-20' '2024-07-17' '2024-04-12' '2023-07-31'
#  '2024-04-06' '2023-08-25' '2023-01-29' '2024-06-13' '2023-03-30'
#  '2024-03-30' '2023-03-04' '2023-02-19' '2023-04-23' '2024-08-29'
#  '2023-12-08' '2024-07-28' '2024-03-17' '2024-01-21' '2024-02-29'
#  '2024-01-30' '2024-04-26' '2023-03-20' '2023-03-24' '2024-06-29'
#  '2024-09-26' '2024-03-23' '2023-01-22' '2024-05-31' '2023-03-22'
#  '2024-05-20']
# --------------------------------------------------
# Feature: HDate
# Unique Values (641): ['2024-04-14' '2024-04-26' '2024-04-28' '2024-11-04' '2024-05-19'
#  '2024-05-18' '2024-05-30' '2024-04-04' '2024-10-05' '2024-04-22'
#  '2024-05-29' '2024-04-15' '2024-05-14' '2024-05-13' '2024-01-04'
#  '2024-04-20' '2024-04-19' '2024-05-20' '2024-05-24' '2024-06-04'
#  '2024-07-05' '2024-04-23' '2024-05-28' '2024-04-16' '2024-04-24'
#  '2024-05-22' '2024-04-30' '2024-05-26' '2024-05-27' '2024-05-15'
#  '2024-05-25' '2024-01-05' '2024-09-05' '2024-02-05' '2024-02-04'
#  '2024-05-04' '2024-04-13' '2024-04-25' '2024-03-05' '2024-08-04'
#  '2024-05-21' '2024-05-05' '2024-04-29' '2024-03-04' '2024-11-05'
#  '2024-12-04' '2024-07-04' '2024-03-17' '2024-02-19' '2024-03-27'
#  '2024-09-02' '2024-02-25' '2024-02-20' '2024-03-18' '2024-03-14'
#  '2024-02-29' '2024-05-02' '2024-03-03' '2024-12-03' '2024-11-03'
#  '2024-10-02' '2024-02-23' '2024-03-15' '2024-03-16' '2024-03-13'
#  '2024-04-03' '2024-03-30' '2024-03-19' '2024-02-18' '2024-03-28'
#  '2024-07-03' '2024-06-02' '2024-06-03' '2024-03-29' '2024-02-27'
#  '2024-03-02' '2024-02-21' '2024-02-28' '2024-02-03' '2024-03-22'
#  '2024-03-20' '2024-03-21' '2024-02-17' '2024-12-02' '2024-10-03'
#  '2024-08-02' '2024-02-02' '2024-09-03' '2024-01-03' '2024-02-14'
#  '2024-02-22' '2024-08-03' '2024-03-25' '2024-07-02' '2024-01-02'
#  '2024-05-03' '2024-02-16' '2024-02-26' '2024-02-24' '2024-03-23'
#  '2024-03-24' '2024-02-13' '2024-03-26' '2024-04-02' '2024-11-02'
#  '2024-04-21' '2024-04-17' '2024-09-04' '2024-04-27' '2024-10-04'
#  '2024-04-18' '2024-02-15' '2024-03-31' '2024-02-09' '2024-01-13'
#  '2024-01-26' '2024-02-01' '2024-02-11' '2024-02-06' '2024-01-06'
#  '2024-02-10' '2024-01-27' '2024-01-24' '2024-01-09' '2024-01-23'
#  '2024-01-07' '2024-01-14' '2024-01-01' '2024-01-16' '2024-02-12'
#  '2024-01-11' '2024-01-31' '2024-01-22' '2024-01-12' '2024-01-08'
#  '2024-01-29' '2024-01-30' '2024-01-17' '2024-01-28' '2024-01-20'
#  '2024-01-10' '2024-01-15' '2024-02-07' '2024-01-25' '2024-02-08'
#  '2024-01-19' '2024-01-18' '2024-01-21' '2024-06-05' '2024-08-05'
#  '2024-12-05' '2024-05-23' '2024-04-05' '2024-05-17' '2024-05-16'
#  '2024-03-09' '2024-03-07' '2023-08-07' '2023-06-03' '2023-09-30'
#  '2024-08-23' '2023-08-26' '2023-08-15' '2023-09-24' '2023-03-27'
#  '2023-07-03' '2023-01-08' '2023-12-28' '2023-08-20' '2024-10-28'
#  '2023-02-08' '2023-09-20' '2023-03-17' '2024-07-10' '2023-04-11'
#  '2023-07-26' '2023-03-09' '2024-11-10' '2023-10-22' '2023-09-08'
#  '2023-04-27' '2023-10-14' '2023-05-05' '2023-03-01' '2023-08-06'
#  '2023-01-17' '2024-04-09' '2024-06-14' '2024-06-06' '2023-04-20'
#  '2023-10-01' '2024-10-31' '2023-11-06' '2023-01-21' '2023-08-04'
#  '2023-11-11' '2024-08-16' '2024-05-10' '2023-07-23' '2023-05-29'
#  '2023-02-15' '2023-12-30' '2023-08-27' '2023-07-20' '2023-12-02'
#  '2023-04-29' '2024-07-25' '2023-08-19' '2024-07-29' '2023-06-27'
#  '2023-12-06' '2023-06-17' '2024-07-13' '2023-02-05' '2024-06-13'
#  '2024-05-31' '2023-01-28' '2024-09-12' '2023-10-13' '2023-06-09'
#  '2023-11-27' '2023-03-11' '2023-06-02' '2023-05-20' '2024-03-11'
#  '2023-05-23' '2023-10-16' '2023-12-12' '2023-06-04' '2023-05-27'
#  '2023-12-22' '2023-03-21' '2023-10-28' '2023-05-15' '2024-06-28'
#  '2023-11-29' '2023-08-29' '2023-08-24' '2023-11-08' '2023-06-20'
#  '2023-10-03' '2024-10-12' '2024-08-11' '2024-06-25' '2023-02-10'
#  '2023-04-16' '2023-11-10' '2024-09-23' '2024-10-19' '2023-05-21'
#  '2024-09-26' '2024-10-10' '2024-11-23' '2024-04-01' '2024-08-13'
#  '2023-03-07' '2024-08-20' '2023-05-02' '2023-04-06' '2024-09-17'
#  '2024-07-07' '2023-02-24' '2023-01-25' '2023-04-30' '2023-08-11'
#  '2024-07-30' '2024-11-19' '2024-10-29' '2024-07-31' '2023-06-18'
#  '2023-06-06' '2023-06-23' '2023-06-16' '2024-09-06' '2023-11-12'
#  '2023-06-07' '2023-08-03' '2023-05-17' '2023-04-26' '2023-09-18'
#  '2023-06-08' '2024-05-07' '2024-11-25' '2023-05-01' '2023-04-21'
#  '2023-09-10' '2024-10-20' '2024-10-06' '2024-07-27' '2024-07-19'
#  '2024-10-01' '2023-06-13' '2023-04-03' '2023-03-30' '2024-12-06'
#  '2024-10-27' '2024-05-06' '2023-06-22' '2024-07-20' '2024-04-11'
#  '2023-07-28' '2023-07-10' '2024-10-14' '2023-06-30' '2023-12-31'
#  '2023-07-14' '2024-05-01' '2024-07-12' '2024-11-16' '2023-02-12'
#  '2024-10-23' '2024-07-26' '2024-08-27' '2023-10-26' '2023-08-12'
#  '2023-04-01' '2023-02-18' '2023-05-24' '2023-04-05' '2023-05-04'
#  '2023-02-06' '2023-04-12' '2024-03-10' '2023-10-05' '2023-09-05'
#  '2023-11-05' '2023-02-19' '2023-08-25' '2023-01-19' '2023-08-23'
#  '2023-10-10' '2024-08-22' '2023-09-06' '2023-02-03' '2024-07-11'
#  '2023-11-21' '2023-05-10' '2023-08-01' '2023-08-30' '2023-09-09'
#  '2023-08-08' '2023-03-29' '2024-07-21' '2023-12-13' '2023-06-14'
#  '2023-08-21' '2023-11-22' '2023-10-15' '2024-06-26' '2024-11-17'
#  '2023-12-01' '2023-02-13' '2024-09-18' '2023-05-30' '2024-10-16'
#  '2023-05-06' '2023-11-25' '2024-12-01' '2023-03-23' '2023-01-26'
#  '2023-10-20' '2023-04-15' '2023-01-13' '2023-05-22' '2024-06-09'
#  '2024-08-06' '2023-02-22' '2024-05-09' '2024-09-19' '2023-10-19'
#  '2024-11-01' '2023-07-19' '2023-12-10' '2024-11-13' '2024-09-11'
#  '2023-05-08' '2023-05-25' '2023-07-07' '2024-10-08' '2024-08-21'
#  '2023-01-12' '2024-04-06' '2024-08-29' '2024-11-12' '2023-03-16'
#  '2023-08-28' '2023-12-21' '2024-09-22' '2023-11-07' '2024-07-01'
#  '2024-06-07' '2023-12-14' '2024-06-10' '2023-05-11' '2024-07-16'
#  '2023-07-29' '2024-07-24' '2024-06-19' '2024-10-21' '2024-06-23'
#  '2024-08-07' '2023-12-11' '2024-11-26' '2023-01-16' '2023-04-04'
#  '2024-09-16' '2024-05-11' '2024-08-28' '2023-05-31' '2023-08-10'
#  '2023-12-09' '2023-12-25' '2023-10-27' '2024-10-24' '2023-11-03'
#  '2024-11-07' '2023-10-12' '2023-06-12' '2023-05-12' '2024-06-01'
#  '2023-12-18' '2023-03-12' '2023-07-12' '2023-12-26' '2024-09-01'
#  '2023-12-24' '2023-12-29' '2023-09-12' '2023-12-16' '2023-12-17'
#  '2024-03-01' '2023-12-27' '2023-12-15' '2023-12-19' '2024-08-01'
#  '2023-12-23' '2023-03-22' '2023-11-13' '2023-07-11' '2023-11-20'
#  '2023-09-27' '2023-11-19' '2023-10-25' '2023-09-29' '2023-07-09'
#  '2023-09-13' '2023-09-25' '2023-04-10' '2023-11-17' '2023-02-11'
#  '2023-10-29' '2023-10-11' '2023-01-11' '2023-11-23' '2023-11-28'
#  '2023-10-18' '2023-01-10' '2023-11-14' '2023-11-26' '2023-09-11'
#  '2023-09-21' '2023-06-10' '2023-10-17' '2023-09-23' '2023-10-31'
#  '2023-10-30' '2023-12-20' '2023-11-15' '2023-03-10' '2023-06-11'
#  '2023-05-09' '2023-08-09' '2023-10-23' '2023-09-19' '2023-10-09'
#  '2023-11-18' '2023-09-22' '2023-10-24' '2023-09-28' '2023-11-24'
#  '2023-11-30' '2023-09-04' '2023-10-21' '2023-10-04' '2023-11-16'
#  '2023-12-03' '2023-12-05' '2023-01-09' '2023-09-15' '2023-09-16'
#  '2023-09-14' '2023-09-03' '2023-02-09' '2023-09-26' '2023-10-02'
#  '2023-11-09' '2023-09-02' '2023-10-07' '2023-11-01' '2023-12-08'
#  '2023-10-06' '2023-12-07' '2023-04-09' '2023-09-01' '2024-07-17'
#  '2023-06-15' '2024-11-28' '2024-10-11' '2024-08-19' '2024-08-31'
#  '2024-06-20' '2023-07-06' '2024-11-24' '2023-09-07' '2024-06-08'
#  '2024-10-25' '2024-09-07' '2024-11-30' '2024-06-21' '2024-08-08'
#  '2024-07-06' '2023-02-25' '2024-04-10' '2023-04-17' '2023-01-24'
#  '2024-08-30' '2024-06-15' '2024-10-15' '2023-04-14' '2023-07-04'
#  '2023-03-28' '2023-02-21' '2023-11-04' '2024-06-22' '2023-02-23'
#  '2024-08-17' '2023-01-31' '2023-02-26' '2023-04-18' '2023-05-13'
#  '2024-07-14' '2024-06-12' '2024-03-06' '2024-09-27' '2023-04-13'
#  '2023-03-02' '2024-09-28' '2024-07-09' '2023-07-13' '2024-10-22'
#  '2023-03-05' '2024-09-30' '2023-04-22' '2023-05-14' '2023-03-20'
#  '2024-06-17' '2024-06-18' '2023-07-18' '2023-04-24' '2024-11-29'
#  '2023-07-16' '2024-11-14' '2024-10-09' '2023-03-26' '2023-07-22'
#  '2023-06-01' '2023-07-30' '2023-06-21' '2024-04-12' '2023-03-06'
#  '2024-06-16' '2023-05-26' '2023-08-05' '2023-04-08' '2024-06-30'
#  '2023-05-16' '2023-04-19' '2024-09-24' '2023-10-08' '2023-02-27'
#  '2023-02-14' '2024-08-24' '2023-08-02' '2024-08-15' '2024-07-08'
#  '2023-02-01' '2023-02-02' '2024-09-21' '2023-11-02' '2023-01-27'
#  '2024-03-08' '2023-03-08' '2023-04-25' '2023-01-23' '2024-11-06'
#  '2024-11-22' '2023-08-22' '2024-03-12' '2023-03-25' '2024-11-27'
#  '2023-02-16' '2023-09-17' '2023-03-15' '2024-08-09' '2023-04-23'
#  '2023-01-22' '2024-07-22' '2024-07-15' '2023-04-02' '2023-05-19'
#  '2023-03-24' '2024-10-30' '2023-01-18' '2023-12-04' '2024-07-23'
#  '2023-07-24' '2024-09-10' '2024-10-07' '2023-07-02' '2023-07-17'
#  '2024-11-15' '2024-09-14' '2023-03-14' '2024-09-20' '2024-09-08'
#  '2024-10-13' '2024-08-25' '2024-11-11' '2023-03-31' '2023-04-28'
#  '2024-06-11' '2024-04-07' '2023-01-29' '2023-07-27' '2024-08-10'
#  '2024-07-18' '2023-01-14' '2024-09-15' '2024-09-29' '2023-06-29'
#  '2023-02-04']
# --------------------------------------------------
# Feature: CropCoveredArea
# Unique Values (61): [ 97  82  92  91  94  84  86  90  89  93  96  80  95  85  83  81  99  88
#   87 100  98  66  65  62  72  64  77  67  76  79  60  73  69  71  75  78
#   74  70  68  61  63  54  51  59  55  57  58  53  56  50  52  46  49  45
#   44  41  48  43  42  40  47]
# --------------------------------------------------
# Feature: CHeight
# Unique Values (231): [ 54  58  91  52  55  51  68  72  78  53  56  59  75  62  64  99  94  50
#   61  84  60  87  77  65  86  70  57  88  67  93  83  95  92  71  74  82
#   66  90  89  96  63  85  98  81 100 101 102 116 108 109 110 107 118  73
#   97 114 106 115 113 105 103  76 111 112 154 224 171 121 104  69  79  80
#  120 117 200 213 141 139 186 209 221 148 244 135 214 241 219 204 125 196
#  237 234 184 248 153 159 243 211 193 180 225 182 156 127 166 227 201 188
#  226 165 183 177 128 176 126 198 205 179 123 142 133 223 197 208 157 167
#  162 206 150  33  49  45  31  39  46  37  38  32  41  48  36  35  47  42
#   44  40  43  30  34  20  29  21  23  25  22  26  27  28  24 191 136 228
#  217 239 173 140 151 202 185 146 190 238 233 232 144 175 250 163 229 137
#  235 199 130 172 203 134 194 161 132 246 138 231 187 195 249 240 131 178
#  247 210 220 207 155 124 216 218 152 169 147 149 119 242 129 215 245 168
#  145 160 174 164 122 192 230 181 158 170 189 212 222 143 236]
# --------------------------------------------------
# Feature: CNext
# Unique Values (11): ['Pea' 'Lentil' 'Sorghum' 'Maize' 'Wheat' 'Soybean' 'Mustard' 'Rice'
#  'Tomato' 'Onion' 'cotton']
# --------------------------------------------------
# Feature: CLast
# Unique Values (10): ['Lentil' 'Pea' 'Maize' 'Sorghum' 'Soybean' 'Wheat' 'Mustard' 'Rice'
#  'Onion' 'Tomato']
# --------------------------------------------------
# Feature: CTransp
# Unique Values (4): ['Transplanting' 'Broadcasting' 'Drilling' 'Seed Drilling']
# --------------------------------------------------
# Feature: IrriType
# Unique Values (4): ['Flood' 'Sprinkler' 'Drip' 'Surface']
# --------------------------------------------------
# Feature: IrriSource
# Unique Values (5): ['Groundwater' 'Canal' 'Rainfed' 'Well' 'Tubewell']
# --------------------------------------------------
# Feature: IrriCount
# Unique Values (6): [4 5 3 6 2 1]
# --------------------------------------------------
# Feature: WaterCov
# Unique Values (62): [ 87  94  99  92  97  85  90  91  86  82  95  80  96  81  89 100  98  93
#   83  84  88  43  48  56  47  53  50  58  54  55  44  41  51  40  59  46
#   60  42  57  45  49  52  28  23  27  37  38  29  30  31  36  24  21  34
#   33  32  25  20  35  26  22  39]
# --------------------------------------------------
# Feature: ExpYield
# Unique Values (33): [17 15 20 16 18 19 13 14 11 12 10 24 22 23 25 21  9  8  5  7  6 26 29 30
#  27 28 42 40 41 45 39 38 37]
# --------------------------------------------------
# Feature: Season
# Unique Values (2): ['Rabi' 'Kharif']
# --------------------------------------------------
# Feature: geometry
# Unique Values (11791): ['POLYGON ((78.18079255482755 17.978971746424413, 78.18109649609544 17.979480756499623, 78.18240014779886 17.978876535906757, 78.18194606686842 17.97819175256819, 78.18079255482755 17.978971746424413))'
#  'POLYGON ((78.17483419891283 17.981508840879556, 78.17648573519998 17.981358701217076, 78.17629165222166 17.98043222964137, 78.17480490336892 17.980527440159026, 78.17484152279883 17.980860676970842, 78.17483419891283 17.981508840879556))'
#  'POLYGON ((78.16888476438905 17.976727511659835, 78.16967940601721 17.976606667541265, 78.16957687161363 17.975500760759186, 78.16871265306865 17.9755263943601, 78.16888476438905 17.976727511659835))'
#  ...
#  'POLYGON ((78.2554603258883 19.19636630652319, 78.25559861543714 19.197959642629087, 78.25965110047623 19.197081804623565, 78.2592456501185 19.195413311154205, 78.2554603258883 19.19636630652319))'
#  'POLYGON ((78.25742756428231 19.195573453548704, 78.25743315703886 19.194046631003385, 78.25407191033652 19.19506451270027, 78.25484930350069 19.196317290173372, 78.25742756428231 19.195573453548704))'
#  'POLYGON ((78.26473996074711 19.225096392031386, 78.26692977703324 19.228770149756777, 78.26844580369283 19.22815250926583, 78.26665705266066 19.22427019760843, 78.26473996074711 19.225096392031386))']
# --------------------------------------------------
# Feature: dataset
# Unique Values (2): ['train' 'test']
# --------------------------------------------------
# Feature: tif_path
# Unique Values (10037): ['downloads/20240412T050649_20240412T051727_T43QHV_RGB_2023-11-25_2024-04-14.tif'
#  'downloads/20240425T051649_20240425T052817_T43QHV_RGB_2023-11-13_2024-04-26.tif'
#  'downloads/20240427T050651_20240427T051439_T43QHV_RGB_2023-12-19_2024-04-28.tif'
#  ...
#  'downloads/20240303T050719_20240303T051936_T43QHB_RGB_2023-11-14_2024-03-04.tif'
#  'downloads/20240323T050649_20240323T051727_T43QHB_RGB_2023-02-12_2024-03-26.tif'
#  'downloads/20240321T051651_20240321T053116_T43QHB_RGB_2023-11-23_2024-03-22.tif']
# --------------------------------------------------
# Feature: ndvi
# Unique Values (10025): [0.10075628 0.1880902  0.20659582 ... 0.17106664 0.2472408  0.24279743]
# --------------------------------------------------
# Feature: evi
# Unique Values (8831): [-0.79368401  0.56424782 -1.45674507 ...  0.77279854 -0.05728064
#  -1.23143992]
# --------------------------------------------------
# Feature: ndwi
# Unique Values (10025): [ 8.48803052 11.49376161 10.16688427 ... 12.3810791  10.57807213
#  10.69407253]
# --------------------------------------------------
# Feature: gndvi
# Unique Values (10025): [0.12715269 0.1878147  0.20655283 ... 0.19746012 0.26166602 0.24226476]
# --------------------------------------------------
# Feature: savi
# Unique Values (10026): [0.15112468 0.28211018 0.3098693  ... 0.2565769  0.37083099 0.36416602]
# --------------------------------------------------
# Feature: msavi
# Unique Values (10019): [4232.59619141 3249.39282227 3741.95605469 ... 3089.12036133 3743.85498047
#  3668.67089844]
# --------------------------------------------------

# %%
# create irrigation efficiency feature
data['IrriEfficiency'] = data['WaterCov'] / (data['IrriCount'] + 1)  # Avoid division by zero
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Drop state column as it is just one state
data.drop(columns=['State'], inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Define helper functions
def process_dates(df):
    """
    Process SDate and HDate to extract meaningful features.
    """
    # Convert dates to datetime
    df['SDate'] = pd.to_datetime(df['SDate'], errors='coerce')
    df['HDate'] = pd.to_datetime(df['HDate'], errors='coerce')
    
    # Extract features
    df['SYear'] = df['SDate'].dt.year
    df['HYear'] = df['HDate'].dt.year
    df['Duration'] = (df['HDate'] - df['SDate']).dt.days  # Calculate duration in days

    # Crop Cycles Per Year
    df['CropCycles'] = 365 / df['Duration']

    # Drop original date columns
    df.drop(columns=['SDate', 'HDate', 'SYear', 'HYear'], inplace=True)
    return df

def preprocess_numerical_features(df, numerical_cols):
    """
    Scale numerical features and apply power transformation to make the features more Gaussian-like.
    """
    # Apply PowerTransformer to stabilize variance and normalize the data
    power_transformer = PowerTransformer()
    
    # Fit and transform the numerical features
    df[numerical_cols] = power_transformer.fit_transform(df[numerical_cols])

    # Return the transformed DataFrame
    return df

# def preprocess_numerical_features(df, numerical_cols):
#     """
#     Scale numerical features and log-transform skewed features.
#     """
#     # Log-transform skewed features
#     skewed_cols = df[numerical_cols].apply(lambda x: x.skew()).abs().sort_values(ascending=False)
#     skewed_cols = skewed_cols[skewed_cols > 1].index  # Columns with skewness > 1
#     df[skewed_cols] = df[skewed_cols].apply(lambda x: np.log1p(x))  # Log transform
    
#     # Scale numerical features
#     scaler = StandardScaler()
#     df[numerical_cols] = scaler.fit_transform(df[numerical_cols])
#     return df
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# --- Main workflow ---
# Process SDate and HDate
data = process_dates(data)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
data.head(10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#     FarmID  category   Crop District Sub-District  CropCoveredArea  CHeight  \
# 0  1326576   Healthy  Paddy    Medak    Kulcharam               97       54
# 1  1326577   Healthy  Paddy    Medak    Kulcharam               82       58
# 2  1326578   Healthy  Paddy    Medak    Kulcharam               92       91
# 3  1331836  Diseased  Paddy    Medak    Kulcharam               91       52
# 4  1326579  Diseased  Paddy    Medak    Kulcharam               94       55
# 5  1326580     Pests  Paddy    Medak    Kulcharam               97       51
# 6  1326581   Healthy  Paddy    Medak    Kulcharam               84       68
# 7   988392   Healthy  Paddy    Medak    Kulcharam               86       72
# 8   718074  Diseased  Paddy    Medak    Kulcharam               90       78
# 9   214818   Healthy  Paddy    Medak    Kulcharam               90       53
#
#     CNext   CLast        CTransp  ...  \
# 0     Pea  Lentil  Transplanting  ...
# 1     Pea  Lentil  Transplanting  ...
# 2     Pea  Lentil  Transplanting  ...
# 3     Pea  Lentil  Transplanting  ...
# 4     Pea  Lentil  Transplanting  ...
# 5     Pea  Lentil  Transplanting  ...
# 6  Lentil     Pea  Transplanting  ...
# 7     Pea  Lentil  Transplanting  ...
# 8     Pea  Lentil  Transplanting  ...
# 9  Lentil     Pea  Transplanting  ...
#
#                                             tif_path      ndvi        evi  \
# 0  downloads/20240412T050649_20240412T051727_T43Q...  0.100756  -0.793684
# 1  downloads/20240425T051649_20240425T052817_T43Q...  0.188090   0.564248
# 2  downloads/20240427T050651_20240427T051439_T43Q...  0.206596  -1.456745
# 3  downloads/20241103T050951_20241103T052004_T43Q...  0.206250   2.206184
# 4  downloads/20240517T050651_20240517T051655_T43Q...  0.179721  -0.743638
# 5  downloads/20240517T050651_20240517T051655_T43Q...  0.139147  -4.770755
# 6  downloads/20240527T050651_20240527T051452_T43Q...  0.049956  -0.553626
# 7  downloads/20240402T050649_20240402T051718_T43Q...  0.211051        inf
# 8  downloads/20241004T050651_20241004T052234_T43Q...  0.101824 -26.822448
# 9  downloads/20240420T051651_20240420T052641_T43Q...  0.024438  -0.254345
#
#         ndwi     gndvi      savi        msavi IrriEfficiency Duration  \
# 0   8.488031  0.127153  0.151125  4232.596191      17.400000      141
# 1  11.493762  0.187815  0.282110  3249.392822      15.666667      165
# 2  10.166884  0.206553  0.309869  3741.956055      24.750000      131
# 3  10.446196  0.220995  0.309350  3673.396729      15.333333      632
# 4   8.665929  0.160657  0.269563  4227.338379      16.166667      159
# 5  10.018032  0.137413  0.208705  3599.652588      14.166667      157
# 6   8.664582  0.064934  0.074929  3914.587646      22.500000      192
# 7  10.583468  0.237314  0.316551  3667.590332      22.750000      112
# 8   6.611994  0.117576  0.152728  5368.100098      21.500000      359
# 9   3.808555  0.039830  0.036655  8770.608398      15.000000      193
#
#    CropCycles
# 0    2.588652
# 1    2.212121
# 2    2.786260
# 3    0.577532
# 4    2.295597
# 5    2.324841
# 6    1.901042
# 7    3.258929
# 8    1.016713
# 9    1.891192
#
# [10 rows x 28 columns]

# %%
data.info()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11791 entries, 0 to 11790
# Data columns (total 28 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FarmID           11791 non-null  int64
#  1   category         8775 non-null   object
#  2   Crop             11791 non-null  object
#  3   District         11791 non-null  object
#  4   Sub-District     11791 non-null  object
#  5   CropCoveredArea  11791 non-null  int64
#  6   CHeight          11791 non-null  int64
#  7   CNext            11791 non-null  object
#  8   CLast            11791 non-null  object
#  9   CTransp          11791 non-null  object
#  10  IrriType         11791 non-null  object
#  11  IrriSource       11791 non-null  object
#  12  IrriCount        11791 non-null  int64
#  13  WaterCov         11791 non-null  int64
#  14  ExpYield         11791 non-null  int64
#  15  Season           11791 non-null  object
#  16  geometry         11791 non-null  object
#  17  dataset          11791 non-null  object
#  18  tif_path         11791 non-null  object
#  19  ndvi             10584 non-null  float64
#  20  evi              10595 non-null  float64
#  21  ndwi             10584 non-null  float64
#  22  gndvi            10584 non-null  float64
#  23  savi             10595 non-null  float64
#  24  msavi            10595 non-null  float64
#  25  IrriEfficiency   11791 non-null  float64
#  26  Duration         11791 non-null  int64
#  27  CropCycles       11791 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 2.5+ MB

# %%
# Split the data into train and test
train = data[data.dataset == 'train'].reset_index(drop=True)
test = data[data.dataset == 'test'].reset_index(drop=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Define columns to drop
to_drop = ['geometry', 'tif_path', 'dataset', 'FarmID']

# Drop specified columns
train.drop(columns=to_drop, inplace=True)
test.drop(columns=to_drop, inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Combine for encoding
data_combined = pd.concat([train, test], ignore_index=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Create a mapping for the target variable 'category' to numeric labels, excluding NaN values
category_mapper = {label: idx for idx, label in enumerate(data_combined['category'].unique()) if pd.notna(label)}
idx_to_category_mapper = {idx: label for idx, label in enumerate(data_combined['category'].unique()) if pd.notna(label)}

# Map the 'category' column to the new 'target' column using the mapping, handling NaN values as needed
data_combined['target'] = data_combined['category'].map(category_mapper)

# Drop the original 'category' column now that we have the 'target' column
data_combined.drop(columns=['category'], inplace=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ##### Encoding of categorical columns

# %%
# Encode categorical columns
categorical_cols = data_combined.select_dtypes(include=['object']).columns
label_encoders = {}
for col in categorical_cols:
    encoder = LabelEncoder()
    data_combined[col] = encoder.fit_transform(data_combined[col])
    label_encoders[col] = encoder
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Identify numerical columns
numerical_cols = data_combined.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_cols.remove('target')  # Exclude target variable
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Check for infinities or extremely large values
inf_cols = data_combined[numerical_cols].apply(lambda col: np.isinf(col).any())
print("Columns with infinity values:", inf_cols[inf_cols].index.tolist())

large_vals = data_combined[numerical_cols].apply(lambda col: (col > 1e308).any())
print("Columns with extremely large values:", large_vals[large_vals].index.tolist())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Columns with infinity values: ['evi', 'CropCycles']
# Columns with extremely large values: ['evi', 'CropCycles']

# %%
# Replace inf or -inf values with NaN (to handle them later)
data_combined[numerical_cols] = data_combined[numerical_cols].replace([np.inf, -np.inf], np.nan)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Cap or clip excessively large values
data_combined[numerical_cols] = data_combined[numerical_cols].clip(upper=1e308)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Impute missing values using IterativeImputer
iterative_imputer = IterativeImputer(max_iter=50, random_state=0)
data_combined[numerical_cols] = iterative_imputer.fit_transform(data_combined[numerical_cols])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Preprocess numerical features
data_combined = preprocess_numerical_features(data_combined, numerical_cols)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
data_combined.info()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11791 entries, 0 to 11790
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             11791 non-null  int32
#  1   District         11791 non-null  int32
#  2   Sub-District     11791 non-null  int32
#  3   CropCoveredArea  11791 non-null  float64
#  4   CHeight          11791 non-null  float64
#  5   CNext            11791 non-null  int32
#  6   CLast            11791 non-null  int32
#  7   CTransp          11791 non-null  int32
#  8   IrriType         11791 non-null  int32
#  9   IrriSource       11791 non-null  int32
#  10  IrriCount        11791 non-null  float64
#  11  WaterCov         11791 non-null  float64
#  12  ExpYield         11791 non-null  float64
#  13  Season           11791 non-null  int32
#  14  ndvi             11791 non-null  float64
#  15  evi              11791 non-null  float64
#  16  ndwi             11791 non-null  float64
#  17  gndvi            11791 non-null  float64
#  18  savi             11791 non-null  float64
#  19  msavi            11791 non-null  float64
#  20  IrriEfficiency   11791 non-null  float64
#  21  Duration         11791 non-null  float64
#  22  CropCycles       11791 non-null  float64
#  23  target           8775 non-null   float64
# dtypes: float64(15), int32(9)
# memory usage: 1.8 MB

# %%
# Split back into train and test
train_encoded = data_combined[data_combined.index < len(train)].reset_index(drop=True)
test_encoded = data_combined[data_combined.index >= len(train)].reset_index(drop=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Separate features and target variable in the train set
X = train_encoded.drop(columns=['target'])
y = train_encoded['target'].astype(int)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Stratified split based on 'target' for training and validation
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Assuming your target variable is named 'target' in the DataFrame 'df'
class_counts = train_encoded['target'].value_counts()

# Print the class counts
print(class_counts)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# target
# 0.0    7214
# 1.0     537
# 2.0     536
# 3.0     488
# Name: count, dtype: int64

# %%
# Initialize StratifiedKFold for cross-validation
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

# Class weights (adjust as needed)
class_weights = {0.0: 1.0, 1.0: 13.5, 2.0: 13.5, 3.0: 14.8}

# Initialize models with class weights for RandomForest and AdaBoost
models = {
    'CatBoost': CatBoostClassifier(
        objective='MultiClass', 
        boosting_type='Plain', 
        random_state=42, 
        class_weights=class_weights
    ),
    'RandomForest': RandomForestClassifier(
        random_state=42, 
        class_weight='balanced'  # Use 'balanced' to automatically adjust class weights
    ),
    'TabNet': TabNetClassifier(
        device_name='cpu'  # 'cuda' if using a GPU
    )
}

# Parameter distributions for hyperparameter tuning (you can adjust these based on your needs)
param_dist_catboost = {
    'learning_rate': [0.01, 0.05, 0.1],
    'depth': [5, 8, 10],
    'iterations': [200, 600, 1000],
    'l2_leaf_reg': [1, 5, 10],
    'early_stopping_rounds': [20],
}

param_dist_rf = {
    'n_estimators': [200, 500, 1000],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'class_weight': ['balanced', None]  # Adjust if needed
}

param_dist_tabnet = {
    'n_d': [8, 16, 32],
    'n_a': [8, 16, 32],
    'n_steps': [3, 5],
    'gamma': [1.0, 1.5],
    'lambda_sparse': [0.01, 0.1],
    'optimizer_params': [{'lr': 1e-3}, {'lr': 1e-4}],  # Example
}

# Function to evaluate models
def evaluate_model(model, X_train, y_train, X_valid, y_valid, class_weights=None):
    # Handle RandomForest with class weights
    if isinstance(model, RandomForestClassifier):
        model.fit(X_train, y_train)  # RandomForest can use 'balanced' directly in the classifier
    
    elif isinstance(model, CatBoostClassifier):
        model.fit(X_train, y_train, class_weights=class_weights)  # CatBoost accepts class_weights as a parameter
    
    elif isinstance(model, TabNetClassifier):
        model.fit(X_train, y_train)  # TabNet doesn't need explicit class weights
    
# # Function to evaluate models
# def evaluate_model(model, X_train, y_train, X_valid, y_valid, class_weights=None):
#     if isinstance(model, AdaBoostClassifier):  # Handle AdaBoost with sample weights
#         sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)
#         model.fit(X_train, y_train, sample_weight=sample_weights)
#     else:  # Other models like RandomForest, CatBoost, and TabNet
#         model.fit(X_train, y_train)

    # Predictions
    y_pred = model.predict(X_valid)
    classification_rep = classification_report(y_valid, y_pred)
    f1 = f1_score(y_valid, y_pred, average='weighted')

    return classification_rep, f1
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %%
# Evaluate models
best_f1 = 0
best_model = None
best_model_name = ""

for model_name, model in models.items():
    print(f"Evaluating {model_name}...")
    
    # Hyperparameter tuning for CatBoost using RandomizedSearchCV
    if model_name == 'CatBoost':
        random_search = RandomizedSearchCV(
            model,               # Model to tune
            param_distributions=param_dist_catboost,  # Corrected to CatBoost's parameters
            n_iter=20,           # Number of random combinations to try
            cv=cv,               # Cross-validation folds
            scoring='f1_weighted',  # Use weighted F1 score
            n_jobs=-1,           # Use all cores
            random_state=42,     # For reproducibility
            verbose=0            # Display progress
        )
        random_search.fit(X_train, y_train)
        best_model_random = random_search.best_estimator_
        f1_random = f1_score(y_valid, best_model_random.predict(X_valid), average='weighted')

        if f1_random > best_f1:
            best_f1 = f1_random
            best_model = best_model_random
            best_model_name = model_name
        print(f"{model_name} - Best F1 Score: {f1_random}")
    
    # Hyperparameter tuning for RandomForest
    elif model_name == 'RandomForest':
        random_search_rf = RandomizedSearchCV(
            model,               # Model to tune
            param_distributions=param_dist_rf,  # Random Forest's parameters
            n_iter=20,           # Number of random combinations to try
            cv=cv,               # Cross-validation folds
            scoring='f1_weighted',  # Use weighted F1 score
            n_jobs=-1,           # Use all cores
            random_state=42,     # For reproducibility
            verbose=1            # Display progress
        )
        random_search_rf.fit(X_train, y_train)
        best_model_rf = random_search_rf.best_estimator_
        f1_rf = f1_score(y_valid, best_model_rf.predict(X_valid), average='weighted')

        if f1_rf > best_f1:
            best_f1 = f1_rf
            best_model = best_model_rf
            best_model_name = model_name
        print(f"{model_name} - Best F1 Score: {f1_rf}")
    
    # Hyperparameter tuning for TabNet
    elif model_name == 'TabNet':
        random_search_tabnet = RandomizedSearchCV(
            model,               # Model to tune
            param_distributions=param_dist_tabnet,  # TabNet's parameters
            n_iter=20,           # Number of random combinations to try
            cv=cv,               # Cross-validation folds
            scoring='f1_weighted',  # Use weighted F1 score
            n_jobs=-1,           # Use all cores
            random_state=42,     # For reproducibility
            verbose=1            # Display progress
        )
        # Ensure X_train is converted to a NumPy array for TabNet
        random_search_tabnet.fit(X_train.to_numpy(), y_train.to_numpy())
        best_model_tabnet = random_search_tabnet.best_estimator_
        f1_tabnet = f1_score(y_valid, best_model_tabnet.predict(X_valid.to_numpy()), average='weighted')

        if f1_tabnet > best_f1:
            best_f1 = f1_tabnet
            best_model = best_model_tabnet
            best_model_name = model_name
        print(f"{model_name} - Best F1 Score: {f1_tabnet}")

# Final output
print(f"\nBest Model: {best_model_name}")
print(f"Best Weighted F1 Score: {best_f1}")
print("Classification Report of Best Model:\n", classification_report(y_valid, best_model.predict(X_valid)))
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Evaluating CatBoost...
# 0:	learn: 1.3670848	total: 680ms	remaining: 11m 19s
# 1:	learn: 1.3467730	total: 987ms	remaining: 8m 12s
# 2:	learn: 1.3329892	total: 1.32s	remaining: 7m 20s
# 3:	learn: 1.3215422	total: 1.6s	remaining: 6m 39s
# 4:	learn: 1.3121001	total: 1.89s	remaining: 6m 16s
# 5:	learn: 1.3049564	total: 2.23s	remaining: 6m 8s
# 6:	learn: 1.2908592	total: 2.48s	remaining: 5m 52s
# 7:	learn: 1.2757841	total: 2.78s	remaining: 5m 44s
# 8:	learn: 1.2583932	total: 3.07s	remaining: 5m 38s
# 9:	learn: 1.2416273	total: 3.34s	remaining: 5m 30s
# 10:	learn: 1.2277538	total: 3.57s	remaining: 5m 20s
# 11:	learn: 1.2099480	total: 3.81s	remaining: 5m 13s
# 12:	learn: 1.2039429	total: 4.04s	remaining: 5m 6s
# 13:	learn: 1.1950691	total: 4.26s	remaining: 4m 59s
# 14:	learn: 1.1788115	total: 4.51s	remaining: 4m 56s
# 15:	learn: 1.1690960	total: 4.75s	remaining: 4m 52s
# 16:	learn: 1.1624141	total: 4.98s	remaining: 4m 47s
# 17:	learn: 1.1470623	total: 5.23s	remaining: 4m 45s
# 18:	learn: 1.1331930	total: 5.45s	remaining: 4m 41s
# 19:	learn: 1.1224989	total: 5.68s	remaining: 4m 38s
# 20:	learn: 1.1110471	total: 5.93s	remaining: 4m 36s
# 21:	learn: 1.1013725	total: 6.16s	remaining: 4m 33s
# 22:	learn: 1.0891608	total: 6.38s	remaining: 4m 31s
# 23:	learn: 1.0772648	total: 6.63s	remaining: 4m 29s
# 24:	learn: 1.0655054	total: 6.91s	remaining: 4m 29s
# 25:	learn: 1.0571817	total: 7.14s	remaining: 4m 27s
# 26:	learn: 1.0432219	total: 7.36s	remaining: 4m 25s
# 27:	learn: 1.0327565	total: 7.58s	remaining: 4m 23s
# 28:	learn: 1.0223435	total: 7.83s	remaining: 4m 22s
# 29:	learn: 1.0106902	total: 8.12s	remaining: 4m 22s
# 30:	learn: 1.0033044	total: 8.48s	remaining: 4m 25s
# 31:	learn: 0.9963583	total: 8.81s	remaining: 4m 26s
# 32:	learn: 0.9899098	total: 9.11s	remaining: 4m 26s
# 33:	learn: 0.9838668	total: 9.43s	remaining: 4m 27s
# 34:	learn: 0.9743903	total: 9.68s	remaining: 4m 26s
# 35:	learn: 0.9675402	total: 9.98s	remaining: 4m 27s
# 36:	learn: 0.9631471	total: 10.3s	remaining: 4m 27s
# 37:	learn: 0.9551797	total: 10.5s	remaining: 4m 26s
# 38:	learn: 0.9479597	total: 10.9s	remaining: 4m 27s
# 39:	learn: 0.9407389	total: 11.2s	remaining: 4m 28s
# 40:	learn: 0.9348703	total: 11.5s	remaining: 4m 28s
# 41:	learn: 0.9219565	total: 12.1s	remaining: 4m 35s
# 42:	learn: 0.9115687	total: 12.4s	remaining: 4m 36s
# 43:	learn: 0.9064131	total: 12.9s	remaining: 4m 39s
# 44:	learn: 0.9015425	total: 13.1s	remaining: 4m 38s
# 45:	learn: 0.8949505	total: 13.4s	remaining: 4m 38s
# 46:	learn: 0.8913311	total: 13.7s	remaining: 4m 38s
# 47:	learn: 0.8860163	total: 14s	remaining: 4m 38s
# 48:	learn: 0.8780056	total: 14.3s	remaining: 4m 37s
# 49:	learn: 0.8718730	total: 14.6s	remaining: 4m 37s
# 50:	learn: 0.8640823	total: 14.8s	remaining: 4m 36s
# 51:	learn: 0.8575888	total: 15.2s	remaining: 4m 36s
# 52:	learn: 0.8524545	total: 15.5s	remaining: 4m 37s
# 53:	learn: 0.8455835	total: 15.9s	remaining: 4m 38s
# 54:	learn: 0.8397251	total: 16.2s	remaining: 4m 38s
# 55:	learn: 0.8345757	total: 16.5s	remaining: 4m 38s
# 56:	learn: 0.8298336	total: 16.8s	remaining: 4m 38s
# 57:	learn: 0.8210014	total: 17.1s	remaining: 4m 37s
# 58:	learn: 0.8168072	total: 17.4s	remaining: 4m 36s
# 59:	learn: 0.8109718	total: 17.7s	remaining: 4m 37s
# 60:	learn: 0.8032285	total: 18s	remaining: 4m 36s
# 61:	learn: 0.7983922	total: 18.2s	remaining: 4m 35s
# 62:	learn: 0.7906605	total: 18.4s	remaining: 4m 34s
# 63:	learn: 0.7852471	total: 18.7s	remaining: 4m 34s
# 64:	learn: 0.7823424	total: 19.1s	remaining: 4m 34s
# 65:	learn: 0.7756527	total: 19.3s	remaining: 4m 33s
# 66:	learn: 0.7683650	total: 19.6s	remaining: 4m 32s
# 67:	learn: 0.7620342	total: 19.8s	remaining: 4m 31s
# 68:	learn: 0.7531748	total: 20.1s	remaining: 4m 30s
# 69:	learn: 0.7475510	total: 20.3s	remaining: 4m 29s
# 70:	learn: 0.7428022	total: 20.5s	remaining: 4m 28s
# 71:	learn: 0.7396638	total: 20.7s	remaining: 4m 27s
# 72:	learn: 0.7325913	total: 21s	remaining: 4m 26s
# 73:	learn: 0.7301215	total: 21.2s	remaining: 4m 25s
# 74:	learn: 0.7250222	total: 21.4s	remaining: 4m 24s
# 75:	learn: 0.7223091	total: 21.7s	remaining: 4m 24s
# 76:	learn: 0.7192565	total: 22.1s	remaining: 4m 24s
# 77:	learn: 0.7132717	total: 22.3s	remaining: 4m 23s
# 78:	learn: 0.7086715	total: 22.6s	remaining: 4m 23s
# 79:	learn: 0.7019524	total: 22.9s	remaining: 4m 23s
# 80:	learn: 0.6968936	total: 23.3s	remaining: 4m 24s
# 81:	learn: 0.6935252	total: 23.6s	remaining: 4m 24s
# 82:	learn: 0.6872309	total: 24.2s	remaining: 4m 27s
# 83:	learn: 0.6814341	total: 24.8s	remaining: 4m 30s
# 84:	learn: 0.6760742	total: 25.2s	remaining: 4m 31s
# 85:	learn: 0.6705981	total: 25.5s	remaining: 4m 30s
# 86:	learn: 0.6650933	total: 25.9s	remaining: 4m 31s
# 87:	learn: 0.6599279	total: 26.1s	remaining: 4m 30s
# 88:	learn: 0.6550049	total: 26.6s	remaining: 4m 32s
# 89:	learn: 0.6480485	total: 27.1s	remaining: 4m 34s
# 90:	learn: 0.6438367	total: 27.7s	remaining: 4m 36s
# 91:	learn: 0.6397145	total: 28.3s	remaining: 4m 39s
# 92:	learn: 0.6351599	total: 28.6s	remaining: 4m 39s
# 93:	learn: 0.6298186	total: 29s	remaining: 4m 39s
# 94:	learn: 0.6255144	total: 29.4s	remaining: 4m 40s
# 95:	learn: 0.6219531	total: 29.8s	remaining: 4m 40s
# 96:	learn: 0.6169771	total: 30.3s	remaining: 4m 42s
# 97:	learn: 0.6139888	total: 30.7s	remaining: 4m 42s
# 98:	learn: 0.6086732	total: 31s	remaining: 4m 42s
# 99:	learn: 0.6045628	total: 31.3s	remaining: 4m 41s
# 100:	learn: 0.6002270	total: 31.6s	remaining: 4m 41s
# 101:	learn: 0.5941278	total: 32s	remaining: 4m 41s
# 102:	learn: 0.5901042	total: 32.2s	remaining: 4m 40s
# 103:	learn: 0.5845659	total: 32.5s	remaining: 4m 39s
# 104:	learn: 0.5816340	total: 32.7s	remaining: 4m 38s
# 105:	learn: 0.5779592	total: 33s	remaining: 4m 38s
# 106:	learn: 0.5734166	total: 33.3s	remaining: 4m 38s
# 107:	learn: 0.5710904	total: 33.6s	remaining: 4m 37s
# 108:	learn: 0.5684883	total: 33.8s	remaining: 4m 36s
# 109:	learn: 0.5638342	total: 34s	remaining: 4m 35s
# 110:	learn: 0.5581744	total: 34.2s	remaining: 4m 34s
# 111:	learn: 0.5540002	total: 34.4s	remaining: 4m 33s
# 112:	learn: 0.5517010	total: 34.7s	remaining: 4m 32s
# 113:	learn: 0.5481871	total: 35s	remaining: 4m 31s
# 114:	learn: 0.5439457	total: 35.2s	remaining: 4m 30s
# 115:	learn: 0.5413933	total: 35.4s	remaining: 4m 29s
# 116:	learn: 0.5397856	total: 35.6s	remaining: 4m 28s
# 117:	learn: 0.5372140	total: 35.8s	remaining: 4m 27s
# 118:	learn: 0.5341358	total: 36s	remaining: 4m 26s
# 119:	learn: 0.5312832	total: 36.2s	remaining: 4m 25s
# 120:	learn: 0.5269096	total: 36.4s	remaining: 4m 24s
# 121:	learn: 0.5230967	total: 36.6s	remaining: 4m 23s
# 122:	learn: 0.5200190	total: 36.9s	remaining: 4m 23s
# 123:	learn: 0.5153276	total: 37.2s	remaining: 4m 22s
# 124:	learn: 0.5120941	total: 37.4s	remaining: 4m 21s
# 125:	learn: 0.5080105	total: 37.6s	remaining: 4m 21s
# 126:	learn: 0.5040367	total: 37.9s	remaining: 4m 20s
# 127:	learn: 0.5011618	total: 38.1s	remaining: 4m 19s
# 128:	learn: 0.4984268	total: 38.3s	remaining: 4m 18s
# 129:	learn: 0.4964676	total: 38.5s	remaining: 4m 17s
# 130:	learn: 0.4937463	total: 38.7s	remaining: 4m 16s
# 131:	learn: 0.4897292	total: 38.9s	remaining: 4m 15s
# 132:	learn: 0.4875193	total: 39.1s	remaining: 4m 14s
# 133:	learn: 0.4857232	total: 39.3s	remaining: 4m 14s
# 134:	learn: 0.4839488	total: 39.5s	remaining: 4m 13s
# 135:	learn: 0.4818661	total: 39.7s	remaining: 4m 12s
# 136:	learn: 0.4785386	total: 40s	remaining: 4m 12s
# 137:	learn: 0.4761795	total: 40.2s	remaining: 4m 11s
# 138:	learn: 0.4741577	total: 40.5s	remaining: 4m 10s
# 139:	learn: 0.4716818	total: 40.7s	remaining: 4m 9s
# 140:	learn: 0.4688891	total: 40.9s	remaining: 4m 9s
# 141:	learn: 0.4651214	total: 41.1s	remaining: 4m 8s
# 142:	learn: 0.4622954	total: 41.4s	remaining: 4m 7s
# 143:	learn: 0.4595210	total: 41.6s	remaining: 4m 7s
# 144:	learn: 0.4571229	total: 41.8s	remaining: 4m 6s
# 145:	learn: 0.4541272	total: 42s	remaining: 4m 5s
# 146:	learn: 0.4507288	total: 42.2s	remaining: 4m 5s
# 147:	learn: 0.4479038	total: 42.4s	remaining: 4m 4s
# 148:	learn: 0.4459860	total: 42.6s	remaining: 4m 3s
# 149:	learn: 0.4424064	total: 42.9s	remaining: 4m 2s
# 150:	learn: 0.4397492	total: 43.1s	remaining: 4m 2s
# 151:	learn: 0.4358286	total: 43.4s	remaining: 4m 1s
# 152:	learn: 0.4328245	total: 43.6s	remaining: 4m 1s
# 153:	learn: 0.4292155	total: 43.8s	remaining: 4m
# 154:	learn: 0.4262931	total: 44s	remaining: 4m
# 155:	learn: 0.4227221	total: 44.3s	remaining: 3m 59s
# 156:	learn: 0.4195657	total: 44.5s	remaining: 3m 59s
# 157:	learn: 0.4168324	total: 44.8s	remaining: 3m 58s
# 158:	learn: 0.4139715	total: 45s	remaining: 3m 58s
# 159:	learn: 0.4109061	total: 45.2s	remaining: 3m 57s
# 160:	learn: 0.4087405	total: 45.4s	remaining: 3m 56s
# 161:	learn: 0.4061198	total: 45.7s	remaining: 3m 56s
# 162:	learn: 0.4031626	total: 45.9s	remaining: 3m 55s
# 163:	learn: 0.4006421	total: 46.1s	remaining: 3m 55s
# 164:	learn: 0.3990797	total: 46.3s	remaining: 3m 54s
# 165:	learn: 0.3968067	total: 46.6s	remaining: 3m 53s
# 166:	learn: 0.3939466	total: 46.8s	remaining: 3m 53s
# 167:	learn: 0.3927404	total: 47s	remaining: 3m 52s
# 168:	learn: 0.3907755	total: 47.2s	remaining: 3m 52s
# 169:	learn: 0.3878330	total: 47.5s	remaining: 3m 51s
# 170:	learn: 0.3856967	total: 47.7s	remaining: 3m 51s
# 171:	learn: 0.3843885	total: 47.9s	remaining: 3m 50s
# 172:	learn: 0.3827896	total: 48.1s	remaining: 3m 50s
# 173:	learn: 0.3805334	total: 48.3s	remaining: 3m 49s
# 174:	learn: 0.3781161	total: 48.6s	remaining: 3m 48s
# 175:	learn: 0.3759479	total: 48.8s	remaining: 3m 48s
# 176:	learn: 0.3734557	total: 49s	remaining: 3m 47s
# 177:	learn: 0.3705537	total: 49.2s	remaining: 3m 47s
# 178:	learn: 0.3688143	total: 49.4s	remaining: 3m 46s
# 179:	learn: 0.3662185	total: 49.6s	remaining: 3m 46s
# 180:	learn: 0.3637867	total: 49.8s	remaining: 3m 45s
# 181:	learn: 0.3605903	total: 50.1s	remaining: 3m 45s
# 182:	learn: 0.3586175	total: 50.3s	remaining: 3m 44s
# 183:	learn: 0.3561868	total: 50.5s	remaining: 3m 43s
# 184:	learn: 0.3538969	total: 50.7s	remaining: 3m 43s
# 185:	learn: 0.3523530	total: 50.9s	remaining: 3m 42s
# 186:	learn: 0.3510466	total: 51.1s	remaining: 3m 42s
# 187:	learn: 0.3487024	total: 51.3s	remaining: 3m 41s
# 188:	learn: 0.3469394	total: 51.5s	remaining: 3m 41s
# 189:	learn: 0.3444558	total: 51.8s	remaining: 3m 40s
# 190:	learn: 0.3426385	total: 52s	remaining: 3m 40s
# 191:	learn: 0.3404771	total: 52.2s	remaining: 3m 39s
# 192:	learn: 0.3382247	total: 52.4s	remaining: 3m 39s
# 193:	learn: 0.3360378	total: 52.6s	remaining: 3m 38s
# 194:	learn: 0.3340450	total: 52.8s	remaining: 3m 37s
# 195:	learn: 0.3316852	total: 53s	remaining: 3m 37s
# 196:	learn: 0.3301717	total: 53.2s	remaining: 3m 36s
# 197:	learn: 0.3279843	total: 53.5s	remaining: 3m 36s
# 198:	learn: 0.3254787	total: 53.7s	remaining: 3m 36s
# 199:	learn: 0.3235148	total: 53.9s	remaining: 3m 35s
# 200:	learn: 0.3224760	total: 54.1s	remaining: 3m 35s
# 201:	learn: 0.3205196	total: 54.3s	remaining: 3m 34s
# 202:	learn: 0.3195593	total: 54.5s	remaining: 3m 34s
# 203:	learn: 0.3182712	total: 54.7s	remaining: 3m 33s
# 204:	learn: 0.3163524	total: 54.9s	remaining: 3m 33s
# 205:	learn: 0.3146932	total: 55.1s	remaining: 3m 32s
# 206:	learn: 0.3129972	total: 55.4s	remaining: 3m 32s
# 207:	learn: 0.3106964	total: 55.6s	remaining: 3m 31s
# 208:	learn: 0.3093683	total: 55.8s	remaining: 3m 31s
# 209:	learn: 0.3080143	total: 56s	remaining: 3m 30s
# 210:	learn: 0.3059076	total: 56.2s	remaining: 3m 30s
# 211:	learn: 0.3043490	total: 56.4s	remaining: 3m 29s
# 212:	learn: 0.3028650	total: 56.6s	remaining: 3m 29s
# 213:	learn: 0.3018201	total: 56.8s	remaining: 3m 28s
# 214:	learn: 0.3000189	total: 57s	remaining: 3m 28s
# 215:	learn: 0.2981650	total: 57.2s	remaining: 3m 27s
# 216:	learn: 0.2966325	total: 57.5s	remaining: 3m 27s
# 217:	learn: 0.2948891	total: 57.7s	remaining: 3m 26s
# 218:	learn: 0.2934409	total: 57.9s	remaining: 3m 26s
# 219:	learn: 0.2915974	total: 58.1s	remaining: 3m 26s
# 220:	learn: 0.2900710	total: 58.3s	remaining: 3m 25s
# 221:	learn: 0.2890766	total: 58.6s	remaining: 3m 25s
# 222:	learn: 0.2869956	total: 58.8s	remaining: 3m 24s
# 223:	learn: 0.2858833	total: 59s	remaining: 3m 24s
# 224:	learn: 0.2848202	total: 59.2s	remaining: 3m 23s
# 225:	learn: 0.2833428	total: 59.4s	remaining: 3m 23s
# 226:	learn: 0.2813785	total: 59.6s	remaining: 3m 22s
# 227:	learn: 0.2795605	total: 59.8s	remaining: 3m 22s
# 228:	learn: 0.2777713	total: 1m	remaining: 3m 22s
# 229:	learn: 0.2763797	total: 1m	remaining: 3m 21s
# 230:	learn: 0.2754424	total: 1m	remaining: 3m 21s
# 231:	learn: 0.2739707	total: 1m	remaining: 3m 20s
# 232:	learn: 0.2727300	total: 1m	remaining: 3m 20s
# 233:	learn: 0.2712389	total: 1m 1s	remaining: 3m 20s
# 234:	learn: 0.2702327	total: 1m 1s	remaining: 3m 20s
# 235:	learn: 0.2689030	total: 1m 1s	remaining: 3m 19s
# 236:	learn: 0.2676005	total: 1m 1s	remaining: 3m 19s
# 237:	learn: 0.2663487	total: 1m 2s	remaining: 3m 19s
# 238:	learn: 0.2649865	total: 1m 2s	remaining: 3m 18s
# 239:	learn: 0.2636685	total: 1m 2s	remaining: 3m 18s
# 240:	learn: 0.2623100	total: 1m 2s	remaining: 3m 18s
# 241:	learn: 0.2605755	total: 1m 3s	remaining: 3m 17s
# 242:	learn: 0.2599804	total: 1m 3s	remaining: 3m 17s
# 243:	learn: 0.2592002	total: 1m 3s	remaining: 3m 16s
# 244:	learn: 0.2574266	total: 1m 3s	remaining: 3m 16s
# 245:	learn: 0.2568571	total: 1m 4s	remaining: 3m 16s
# 246:	learn: 0.2559721	total: 1m 4s	remaining: 3m 15s
# 247:	learn: 0.2548865	total: 1m 4s	remaining: 3m 15s
# 248:	learn: 0.2540312	total: 1m 4s	remaining: 3m 15s
# 249:	learn: 0.2530853	total: 1m 4s	remaining: 3m 14s
# 250:	learn: 0.2517176	total: 1m 5s	remaining: 3m 14s
# 251:	learn: 0.2507460	total: 1m 5s	remaining: 3m 14s
# 252:	learn: 0.2496052	total: 1m 5s	remaining: 3m 14s
# 253:	learn: 0.2485150	total: 1m 6s	remaining: 3m 13s
# 254:	learn: 0.2478012	total: 1m 6s	remaining: 3m 13s
# 255:	learn: 0.2467360	total: 1m 6s	remaining: 3m 13s
# 256:	learn: 0.2456508	total: 1m 6s	remaining: 3m 12s
# 257:	learn: 0.2441725	total: 1m 6s	remaining: 3m 12s
# 258:	learn: 0.2431838	total: 1m 7s	remaining: 3m 12s
# 259:	learn: 0.2418793	total: 1m 7s	remaining: 3m 11s
# 260:	learn: 0.2408840	total: 1m 7s	remaining: 3m 11s
# 261:	learn: 0.2399963	total: 1m 7s	remaining: 3m 11s
# 262:	learn: 0.2390709	total: 1m 8s	remaining: 3m 10s
# 263:	learn: 0.2375491	total: 1m 8s	remaining: 3m 10s
# 264:	learn: 0.2362511	total: 1m 8s	remaining: 3m 10s
# 265:	learn: 0.2348273	total: 1m 8s	remaining: 3m 9s
# 266:	learn: 0.2335993	total: 1m 9s	remaining: 3m 9s
# 267:	learn: 0.2328239	total: 1m 9s	remaining: 3m 9s
# 268:	learn: 0.2319472	total: 1m 9s	remaining: 3m 9s
# 269:	learn: 0.2312787	total: 1m 9s	remaining: 3m 8s
# 270:	learn: 0.2303616	total: 1m 10s	remaining: 3m 8s
# 271:	learn: 0.2294704	total: 1m 10s	remaining: 3m 8s
# 272:	learn: 0.2284819	total: 1m 10s	remaining: 3m 8s
# 273:	learn: 0.2272906	total: 1m 11s	remaining: 3m 8s
# 274:	learn: 0.2265303	total: 1m 11s	remaining: 3m 8s
# 275:	learn: 0.2255650	total: 1m 11s	remaining: 3m 8s
# 276:	learn: 0.2240817	total: 1m 12s	remaining: 3m 8s
# 277:	learn: 0.2230738	total: 1m 12s	remaining: 3m 7s
# 278:	learn: 0.2221246	total: 1m 12s	remaining: 3m 7s
# 279:	learn: 0.2212888	total: 1m 12s	remaining: 3m 7s
# 280:	learn: 0.2201682	total: 1m 13s	remaining: 3m 6s
# 281:	learn: 0.2189887	total: 1m 13s	remaining: 3m 6s
# 282:	learn: 0.2183338	total: 1m 13s	remaining: 3m 7s
# 283:	learn: 0.2170150	total: 1m 14s	remaining: 3m 7s
# 284:	learn: 0.2161779	total: 1m 14s	remaining: 3m 6s
# 285:	learn: 0.2151187	total: 1m 14s	remaining: 3m 6s
# 286:	learn: 0.2143044	total: 1m 14s	remaining: 3m 6s
# 287:	learn: 0.2137386	total: 1m 15s	remaining: 3m 5s
# 288:	learn: 0.2128234	total: 1m 15s	remaining: 3m 5s
# 289:	learn: 0.2118520	total: 1m 15s	remaining: 3m 5s
# 290:	learn: 0.2106470	total: 1m 15s	remaining: 3m 4s
# 291:	learn: 0.2092347	total: 1m 16s	remaining: 3m 4s
# 292:	learn: 0.2085732	total: 1m 16s	remaining: 3m 4s
# 293:	learn: 0.2077067	total: 1m 16s	remaining: 3m 4s
# 294:	learn: 0.2068138	total: 1m 16s	remaining: 3m 3s
# 295:	learn: 0.2061593	total: 1m 17s	remaining: 3m 3s
# 296:	learn: 0.2050722	total: 1m 17s	remaining: 3m 3s
# 297:	learn: 0.2038749	total: 1m 17s	remaining: 3m 3s
# 298:	learn: 0.2031062	total: 1m 18s	remaining: 3m 2s
# 299:	learn: 0.2021958	total: 1m 18s	remaining: 3m 2s
# 300:	learn: 0.2014143	total: 1m 18s	remaining: 3m 2s
# 301:	learn: 0.2001574	total: 1m 18s	remaining: 3m 2s
# 302:	learn: 0.1992324	total: 1m 18s	remaining: 3m 1s
# 303:	learn: 0.1986259	total: 1m 19s	remaining: 3m 1s
# 304:	learn: 0.1980704	total: 1m 19s	remaining: 3m 1s
# 305:	learn: 0.1970774	total: 1m 19s	remaining: 3m
# 306:	learn: 0.1962948	total: 1m 20s	remaining: 3m
# 307:	learn: 0.1952194	total: 1m 20s	remaining: 3m
# 308:	learn: 0.1945737	total: 1m 20s	remaining: 2m 59s
# 309:	learn: 0.1940382	total: 1m 20s	remaining: 2m 59s
# 310:	learn: 0.1930545	total: 1m 20s	remaining: 2m 59s
# 311:	learn: 0.1920839	total: 1m 21s	remaining: 2m 59s
# 312:	learn: 0.1913706	total: 1m 21s	remaining: 2m 58s
# 313:	learn: 0.1905266	total: 1m 21s	remaining: 2m 58s
# 314:	learn: 0.1896445	total: 1m 21s	remaining: 2m 58s
# 315:	learn: 0.1888150	total: 1m 22s	remaining: 2m 57s
# 316:	learn: 0.1880154	total: 1m 22s	remaining: 2m 57s
# 317:	learn: 0.1873132	total: 1m 22s	remaining: 2m 57s
# 318:	learn: 0.1865307	total: 1m 22s	remaining: 2m 56s
# 319:	learn: 0.1858251	total: 1m 23s	remaining: 2m 56s
# 320:	learn: 0.1849210	total: 1m 23s	remaining: 2m 56s
# 321:	learn: 0.1840629	total: 1m 23s	remaining: 2m 55s
# 322:	learn: 0.1834943	total: 1m 23s	remaining: 2m 55s
# 323:	learn: 0.1828667	total: 1m 23s	remaining: 2m 55s
# 324:	learn: 0.1822374	total: 1m 24s	remaining: 2m 54s
# 325:	learn: 0.1812204	total: 1m 24s	remaining: 2m 54s
# 326:	learn: 0.1805569	total: 1m 24s	remaining: 2m 54s
# 327:	learn: 0.1794600	total: 1m 24s	remaining: 2m 53s
# 328:	learn: 0.1785108	total: 1m 25s	remaining: 2m 53s
# 329:	learn: 0.1778684	total: 1m 25s	remaining: 2m 53s
# 330:	learn: 0.1772654	total: 1m 25s	remaining: 2m 52s
# 331:	learn: 0.1765445	total: 1m 25s	remaining: 2m 52s
# 332:	learn: 0.1760688	total: 1m 25s	remaining: 2m 52s
# 333:	learn: 0.1753251	total: 1m 26s	remaining: 2m 51s
# 334:	learn: 0.1746728	total: 1m 26s	remaining: 2m 51s
# 335:	learn: 0.1741215	total: 1m 26s	remaining: 2m 51s
# 336:	learn: 0.1734249	total: 1m 26s	remaining: 2m 51s
# 337:	learn: 0.1728229	total: 1m 27s	remaining: 2m 50s
# 338:	learn: 0.1722994	total: 1m 27s	remaining: 2m 50s
# 339:	learn: 0.1716129	total: 1m 27s	remaining: 2m 50s
# 340:	learn: 0.1710999	total: 1m 27s	remaining: 2m 49s
# 341:	learn: 0.1701542	total: 1m 28s	remaining: 2m 49s
# 342:	learn: 0.1695363	total: 1m 28s	remaining: 2m 49s
# 343:	learn: 0.1689352	total: 1m 28s	remaining: 2m 48s
# 344:	learn: 0.1681497	total: 1m 28s	remaining: 2m 48s
# 345:	learn: 0.1675560	total: 1m 28s	remaining: 2m 48s
# 346:	learn: 0.1670995	total: 1m 29s	remaining: 2m 47s
# 347:	learn: 0.1665777	total: 1m 29s	remaining: 2m 47s
# 348:	learn: 0.1658257	total: 1m 29s	remaining: 2m 47s
# 349:	learn: 0.1652412	total: 1m 29s	remaining: 2m 47s
# 350:	learn: 0.1646712	total: 1m 30s	remaining: 2m 46s
# 351:	learn: 0.1640553	total: 1m 30s	remaining: 2m 47s
# 352:	learn: 0.1636738	total: 1m 31s	remaining: 2m 46s
# 353:	learn: 0.1630858	total: 1m 31s	remaining: 2m 46s
# 354:	learn: 0.1626287	total: 1m 31s	remaining: 2m 46s
# 355:	learn: 0.1618877	total: 1m 31s	remaining: 2m 46s
# 356:	learn: 0.1610848	total: 1m 32s	remaining: 2m 45s
# 357:	learn: 0.1605170	total: 1m 32s	remaining: 2m 45s
# 358:	learn: 0.1598338	total: 1m 32s	remaining: 2m 45s
# 359:	learn: 0.1592491	total: 1m 32s	remaining: 2m 45s
# 360:	learn: 0.1586093	total: 1m 33s	remaining: 2m 44s
# 361:	learn: 0.1582189	total: 1m 33s	remaining: 2m 44s
# 362:	learn: 0.1574989	total: 1m 33s	remaining: 2m 44s
# 363:	learn: 0.1569349	total: 1m 33s	remaining: 2m 43s
# 364:	learn: 0.1560328	total: 1m 34s	remaining: 2m 43s
# 365:	learn: 0.1553901	total: 1m 34s	remaining: 2m 43s
# 366:	learn: 0.1547242	total: 1m 34s	remaining: 2m 43s
# 367:	learn: 0.1542133	total: 1m 34s	remaining: 2m 42s
# 368:	learn: 0.1538699	total: 1m 34s	remaining: 2m 42s
# 369:	learn: 0.1533034	total: 1m 35s	remaining: 2m 42s
# 370:	learn: 0.1527228	total: 1m 35s	remaining: 2m 41s
# 371:	learn: 0.1521233	total: 1m 35s	remaining: 2m 41s
# 372:	learn: 0.1516413	total: 1m 35s	remaining: 2m 41s
# 373:	learn: 0.1511787	total: 1m 36s	remaining: 2m 40s
# 374:	learn: 0.1505449	total: 1m 36s	remaining: 2m 40s
# 375:	learn: 0.1500833	total: 1m 36s	remaining: 2m 40s
# 376:	learn: 0.1495630	total: 1m 36s	remaining: 2m 39s
# 377:	learn: 0.1491880	total: 1m 37s	remaining: 2m 39s
# 378:	learn: 0.1487899	total: 1m 37s	remaining: 2m 39s
# 379:	learn: 0.1484381	total: 1m 37s	remaining: 2m 39s
# 380:	learn: 0.1481153	total: 1m 37s	remaining: 2m 38s
# 381:	learn: 0.1474686	total: 1m 37s	remaining: 2m 38s
# 382:	learn: 0.1470103	total: 1m 38s	remaining: 2m 38s
# 383:	learn: 0.1464123	total: 1m 38s	remaining: 2m 37s
# 384:	learn: 0.1460861	total: 1m 38s	remaining: 2m 37s
# 385:	learn: 0.1456612	total: 1m 38s	remaining: 2m 37s
# 386:	learn: 0.1451394	total: 1m 38s	remaining: 2m 36s
# 387:	learn: 0.1446554	total: 1m 39s	remaining: 2m 36s
# 388:	learn: 0.1441145	total: 1m 39s	remaining: 2m 36s
# 389:	learn: 0.1435818	total: 1m 39s	remaining: 2m 35s
# 390:	learn: 0.1430307	total: 1m 39s	remaining: 2m 35s
# 391:	learn: 0.1426165	total: 1m 40s	remaining: 2m 35s
# 392:	learn: 0.1423636	total: 1m 40s	remaining: 2m 34s
# 393:	learn: 0.1418589	total: 1m 40s	remaining: 2m 34s
# 394:	learn: 0.1413125	total: 1m 40s	remaining: 2m 34s
# 395:	learn: 0.1409018	total: 1m 40s	remaining: 2m 33s
# 396:	learn: 0.1404256	total: 1m 41s	remaining: 2m 33s
# 397:	learn: 0.1401747	total: 1m 41s	remaining: 2m 33s
# 398:	learn: 0.1396432	total: 1m 41s	remaining: 2m 32s
# 399:	learn: 0.1393911	total: 1m 41s	remaining: 2m 32s
# 400:	learn: 0.1390250	total: 1m 41s	remaining: 2m 32s
# 401:	learn: 0.1385900	total: 1m 42s	remaining: 2m 31s
# 402:	learn: 0.1380065	total: 1m 42s	remaining: 2m 31s
# 403:	learn: 0.1374660	total: 1m 42s	remaining: 2m 31s
# 404:	learn: 0.1370269	total: 1m 42s	remaining: 2m 31s
# 405:	learn: 0.1366360	total: 1m 43s	remaining: 2m 30s
# 406:	learn: 0.1361905	total: 1m 43s	remaining: 2m 30s
# 407:	learn: 0.1356854	total: 1m 43s	remaining: 2m 30s
# 408:	learn: 0.1351566	total: 1m 43s	remaining: 2m 29s
# 409:	learn: 0.1345693	total: 1m 43s	remaining: 2m 29s
# 410:	learn: 0.1343195	total: 1m 44s	remaining: 2m 29s
# 411:	learn: 0.1337753	total: 1m 44s	remaining: 2m 29s
# 412:	learn: 0.1333435	total: 1m 44s	remaining: 2m 28s
# 413:	learn: 0.1330258	total: 1m 44s	remaining: 2m 28s
# 414:	learn: 0.1327541	total: 1m 45s	remaining: 2m 28s
# 415:	learn: 0.1323829	total: 1m 45s	remaining: 2m 27s
# 416:	learn: 0.1320437	total: 1m 45s	remaining: 2m 27s
# 417:	learn: 0.1315744	total: 1m 45s	remaining: 2m 27s
# 418:	learn: 0.1310713	total: 1m 46s	remaining: 2m 27s
# 419:	learn: 0.1306571	total: 1m 46s	remaining: 2m 26s
# 420:	learn: 0.1303578	total: 1m 46s	remaining: 2m 26s
# 421:	learn: 0.1300026	total: 1m 46s	remaining: 2m 26s
# 422:	learn: 0.1297593	total: 1m 46s	remaining: 2m 25s
# 423:	learn: 0.1292927	total: 1m 47s	remaining: 2m 25s
# 424:	learn: 0.1287779	total: 1m 47s	remaining: 2m 25s
# 425:	learn: 0.1284519	total: 1m 47s	remaining: 2m 25s
# 426:	learn: 0.1279185	total: 1m 47s	remaining: 2m 24s
# 427:	learn: 0.1274356	total: 1m 48s	remaining: 2m 24s
# 428:	learn: 0.1270189	total: 1m 48s	remaining: 2m 24s
# 429:	learn: 0.1266790	total: 1m 48s	remaining: 2m 23s
# 430:	learn: 0.1261795	total: 1m 48s	remaining: 2m 23s
# 431:	learn: 0.1257870	total: 1m 48s	remaining: 2m 23s
# 432:	learn: 0.1254120	total: 1m 49s	remaining: 2m 22s
# 433:	learn: 0.1250097	total: 1m 49s	remaining: 2m 22s
# 434:	learn: 0.1246172	total: 1m 49s	remaining: 2m 22s
# 435:	learn: 0.1242912	total: 1m 49s	remaining: 2m 22s
# 436:	learn: 0.1240394	total: 1m 49s	remaining: 2m 21s
# 437:	learn: 0.1236047	total: 1m 50s	remaining: 2m 21s
# 438:	learn: 0.1232703	total: 1m 50s	remaining: 2m 21s
# 439:	learn: 0.1227179	total: 1m 50s	remaining: 2m 20s
# 440:	learn: 0.1223901	total: 1m 50s	remaining: 2m 20s
# 441:	learn: 0.1220379	total: 1m 51s	remaining: 2m 20s
# 442:	learn: 0.1215638	total: 1m 51s	remaining: 2m 19s
# 443:	learn: 0.1211060	total: 1m 51s	remaining: 2m 19s
# 444:	learn: 0.1207273	total: 1m 51s	remaining: 2m 19s
# 445:	learn: 0.1204846	total: 1m 51s	remaining: 2m 18s
# 446:	learn: 0.1201487	total: 1m 52s	remaining: 2m 18s
# 447:	learn: 0.1198821	total: 1m 52s	remaining: 2m 18s
# 448:	learn: 0.1193388	total: 1m 52s	remaining: 2m 18s
# 449:	learn: 0.1188650	total: 1m 52s	remaining: 2m 17s
# 450:	learn: 0.1185116	total: 1m 52s	remaining: 2m 17s
# 451:	learn: 0.1181782	total: 1m 53s	remaining: 2m 17s
# 452:	learn: 0.1178055	total: 1m 53s	remaining: 2m 16s
# 453:	learn: 0.1172438	total: 1m 53s	remaining: 2m 16s
# 454:	learn: 0.1170440	total: 1m 53s	remaining: 2m 16s
# 455:	learn: 0.1165570	total: 1m 53s	remaining: 2m 15s
# 456:	learn: 0.1162205	total: 1m 54s	remaining: 2m 15s
# 457:	learn: 0.1158921	total: 1m 54s	remaining: 2m 15s
# 458:	learn: 0.1156296	total: 1m 54s	remaining: 2m 15s
# 459:	learn: 0.1152709	total: 1m 54s	remaining: 2m 14s
# 460:	learn: 0.1149054	total: 1m 55s	remaining: 2m 14s
# 461:	learn: 0.1146417	total: 1m 55s	remaining: 2m 14s
# 462:	learn: 0.1143551	total: 1m 55s	remaining: 2m 13s
# 463:	learn: 0.1139919	total: 1m 55s	remaining: 2m 13s
# 464:	learn: 0.1135865	total: 1m 55s	remaining: 2m 13s
# 465:	learn: 0.1133385	total: 1m 56s	remaining: 2m 13s
# 466:	learn: 0.1129884	total: 1m 56s	remaining: 2m 12s
# 467:	learn: 0.1125088	total: 1m 56s	remaining: 2m 12s
# 468:	learn: 0.1119809	total: 1m 56s	remaining: 2m 12s
# 469:	learn: 0.1116072	total: 1m 56s	remaining: 2m 11s
# 470:	learn: 0.1111059	total: 1m 57s	remaining: 2m 11s
# 471:	learn: 0.1108100	total: 1m 57s	remaining: 2m 11s
# 472:	learn: 0.1104475	total: 1m 57s	remaining: 2m 11s
# 473:	learn: 0.1101939	total: 1m 57s	remaining: 2m 10s
# 474:	learn: 0.1098193	total: 1m 58s	remaining: 2m 10s
# 475:	learn: 0.1093944	total: 1m 58s	remaining: 2m 10s
# 476:	learn: 0.1090631	total: 1m 58s	remaining: 2m 10s
# 477:	learn: 0.1087279	total: 1m 58s	remaining: 2m 9s
# 478:	learn: 0.1084124	total: 1m 59s	remaining: 2m 9s
# 479:	learn: 0.1080786	total: 1m 59s	remaining: 2m 9s
# 480:	learn: 0.1078224	total: 1m 59s	remaining: 2m 9s
# 481:	learn: 0.1075791	total: 2m	remaining: 2m 9s
# 482:	learn: 0.1072502	total: 2m	remaining: 2m 8s
# 483:	learn: 0.1068285	total: 2m	remaining: 2m 8s
# 484:	learn: 0.1064145	total: 2m	remaining: 2m 8s
# 485:	learn: 0.1060989	total: 2m 1s	remaining: 2m 8s
# 486:	learn: 0.1056954	total: 2m 1s	remaining: 2m 7s
# 487:	learn: 0.1055372	total: 2m 1s	remaining: 2m 7s
# 488:	learn: 0.1052944	total: 2m 1s	remaining: 2m 7s
# 489:	learn: 0.1048853	total: 2m 2s	remaining: 2m 7s
# 490:	learn: 0.1045349	total: 2m 2s	remaining: 2m 7s
# 491:	learn: 0.1042042	total: 2m 2s	remaining: 2m 6s
# 492:	learn: 0.1037865	total: 2m 3s	remaining: 2m 6s
# 493:	learn: 0.1035416	total: 2m 3s	remaining: 2m 6s
# 494:	learn: 0.1031794	total: 2m 3s	remaining: 2m 6s
# 495:	learn: 0.1028134	total: 2m 3s	remaining: 2m 5s
# 496:	learn: 0.1023825	total: 2m 4s	remaining: 2m 5s
# 497:	learn: 0.1020712	total: 2m 4s	remaining: 2m 5s
# 498:	learn: 0.1017912	total: 2m 4s	remaining: 2m 5s
# 499:	learn: 0.1015265	total: 2m 4s	remaining: 2m 4s
# 500:	learn: 0.1013262	total: 2m 5s	remaining: 2m 4s
# 501:	learn: 0.1010921	total: 2m 5s	remaining: 2m 4s
# 502:	learn: 0.1009323	total: 2m 5s	remaining: 2m 4s
# 503:	learn: 0.1006046	total: 2m 5s	remaining: 2m 3s
# 504:	learn: 0.1003430	total: 2m 6s	remaining: 2m 3s
# 505:	learn: 0.1000675	total: 2m 6s	remaining: 2m 3s
# 506:	learn: 0.0996156	total: 2m 6s	remaining: 2m 3s
# 507:	learn: 0.0992642	total: 2m 6s	remaining: 2m 2s
# 508:	learn: 0.0989899	total: 2m 7s	remaining: 2m 2s
# 509:	learn: 0.0987840	total: 2m 7s	remaining: 2m 2s
# 510:	learn: 0.0984266	total: 2m 7s	remaining: 2m 2s
# 511:	learn: 0.0980816	total: 2m 7s	remaining: 2m 1s
# 512:	learn: 0.0977740	total: 2m 8s	remaining: 2m 2s
# 513:	learn: 0.0975448	total: 2m 9s	remaining: 2m 2s
# 514:	learn: 0.0972821	total: 2m 9s	remaining: 2m 1s
# 515:	learn: 0.0968675	total: 2m 9s	remaining: 2m 1s
# 516:	learn: 0.0965706	total: 2m 10s	remaining: 2m 1s
# 517:	learn: 0.0963346	total: 2m 10s	remaining: 2m 1s
# 518:	learn: 0.0961121	total: 2m 11s	remaining: 2m 1s
# 519:	learn: 0.0959891	total: 2m 11s	remaining: 2m 1s
# 520:	learn: 0.0957393	total: 2m 12s	remaining: 2m 1s
# 521:	learn: 0.0955964	total: 2m 12s	remaining: 2m 1s
# 522:	learn: 0.0952132	total: 2m 12s	remaining: 2m 1s
# 523:	learn: 0.0950094	total: 2m 13s	remaining: 2m 1s
# 524:	learn: 0.0946654	total: 2m 13s	remaining: 2m
# 525:	learn: 0.0944330	total: 2m 13s	remaining: 2m
# 526:	learn: 0.0942283	total: 2m 14s	remaining: 2m
# 527:	learn: 0.0940736	total: 2m 14s	remaining: 2m
# 528:	learn: 0.0937514	total: 2m 14s	remaining: 2m
# 529:	learn: 0.0935046	total: 2m 15s	remaining: 1m 59s
# 530:	learn: 0.0932351	total: 2m 15s	remaining: 1m 59s
# 531:	learn: 0.0930395	total: 2m 15s	remaining: 1m 59s
# 532:	learn: 0.0928712	total: 2m 16s	remaining: 1m 59s
# 533:	learn: 0.0926360	total: 2m 16s	remaining: 1m 59s
# 534:	learn: 0.0922867	total: 2m 16s	remaining: 1m 59s
# 535:	learn: 0.0921374	total: 2m 17s	remaining: 1m 58s
# 536:	learn: 0.0919467	total: 2m 17s	remaining: 1m 58s
# 537:	learn: 0.0915873	total: 2m 17s	remaining: 1m 58s
# 538:	learn: 0.0913067	total: 2m 18s	remaining: 1m 58s
# 539:	learn: 0.0910028	total: 2m 18s	remaining: 1m 57s
# 540:	learn: 0.0906769	total: 2m 18s	remaining: 1m 57s
# 541:	learn: 0.0904723	total: 2m 18s	remaining: 1m 57s
# 542:	learn: 0.0902575	total: 2m 19s	remaining: 1m 57s
# 543:	learn: 0.0900245	total: 2m 19s	remaining: 1m 56s
# 544:	learn: 0.0897829	total: 2m 19s	remaining: 1m 56s
# 545:	learn: 0.0894298	total: 2m 19s	remaining: 1m 56s
# 546:	learn: 0.0891719	total: 2m 19s	remaining: 1m 55s
# 547:	learn: 0.0890029	total: 2m 20s	remaining: 1m 55s
# 548:	learn: 0.0888119	total: 2m 20s	remaining: 1m 55s
# 549:	learn: 0.0885740	total: 2m 20s	remaining: 1m 55s
# 550:	learn: 0.0883073	total: 2m 20s	remaining: 1m 54s
# 551:	learn: 0.0880492	total: 2m 21s	remaining: 1m 54s
# 552:	learn: 0.0878550	total: 2m 21s	remaining: 1m 54s
# 553:	learn: 0.0876957	total: 2m 21s	remaining: 1m 54s
# 554:	learn: 0.0874884	total: 2m 21s	remaining: 1m 53s
# 555:	learn: 0.0873649	total: 2m 22s	remaining: 1m 53s
# 556:	learn: 0.0871465	total: 2m 22s	remaining: 1m 53s
# 557:	learn: 0.0869471	total: 2m 22s	remaining: 1m 52s
# 558:	learn: 0.0867955	total: 2m 22s	remaining: 1m 52s
# 559:	learn: 0.0865889	total: 2m 22s	remaining: 1m 52s
# 560:	learn: 0.0863667	total: 2m 23s	remaining: 1m 52s
# 561:	learn: 0.0860970	total: 2m 23s	remaining: 1m 51s
# 562:	learn: 0.0859147	total: 2m 23s	remaining: 1m 51s
# 563:	learn: 0.0857469	total: 2m 23s	remaining: 1m 51s
# 564:	learn: 0.0855628	total: 2m 24s	remaining: 1m 50s
# 565:	learn: 0.0853929	total: 2m 24s	remaining: 1m 50s
# 566:	learn: 0.0851616	total: 2m 24s	remaining: 1m 50s
# 567:	learn: 0.0849902	total: 2m 24s	remaining: 1m 50s
# 568:	learn: 0.0847311	total: 2m 24s	remaining: 1m 49s
# 569:	learn: 0.0845448	total: 2m 25s	remaining: 1m 49s
# 570:	learn: 0.0843909	total: 2m 25s	remaining: 1m 49s
# 571:	learn: 0.0842369	total: 2m 25s	remaining: 1m 48s
# 572:	learn: 0.0839944	total: 2m 25s	remaining: 1m 48s
# 573:	learn: 0.0838108	total: 2m 25s	remaining: 1m 48s
# 574:	learn: 0.0835471	total: 2m 26s	remaining: 1m 47s
# 575:	learn: 0.0832563	total: 2m 26s	remaining: 1m 47s
# 576:	learn: 0.0830559	total: 2m 26s	remaining: 1m 47s
# 577:	learn: 0.0827898	total: 2m 26s	remaining: 1m 47s
# 578:	learn: 0.0826476	total: 2m 26s	remaining: 1m 46s
# 579:	learn: 0.0824264	total: 2m 27s	remaining: 1m 46s
# 580:	learn: 0.0823478	total: 2m 27s	remaining: 1m 46s
# 581:	learn: 0.0821619	total: 2m 27s	remaining: 1m 46s
# 582:	learn: 0.0820232	total: 2m 27s	remaining: 1m 45s
# 583:	learn: 0.0819066	total: 2m 27s	remaining: 1m 45s
# 584:	learn: 0.0817051	total: 2m 28s	remaining: 1m 45s
# 585:	learn: 0.0814696	total: 2m 28s	remaining: 1m 44s
# 586:	learn: 0.0812189	total: 2m 28s	remaining: 1m 44s
# 587:	learn: 0.0810235	total: 2m 28s	remaining: 1m 44s
# 588:	learn: 0.0808760	total: 2m 29s	remaining: 1m 43s
# 589:	learn: 0.0807088	total: 2m 29s	remaining: 1m 43s
# 590:	learn: 0.0804570	total: 2m 29s	remaining: 1m 43s
# 591:	learn: 0.0801891	total: 2m 29s	remaining: 1m 43s
# 592:	learn: 0.0799204	total: 2m 29s	remaining: 1m 42s
# 593:	learn: 0.0796471	total: 2m 30s	remaining: 1m 42s
# 594:	learn: 0.0794316	total: 2m 30s	remaining: 1m 42s
# 595:	learn: 0.0792739	total: 2m 30s	remaining: 1m 42s
# 596:	learn: 0.0790924	total: 2m 30s	remaining: 1m 41s
# 597:	learn: 0.0788074	total: 2m 31s	remaining: 1m 41s
# 598:	learn: 0.0786657	total: 2m 31s	remaining: 1m 41s
# 599:	learn: 0.0785721	total: 2m 32s	remaining: 1m 41s
# 600:	learn: 0.0783212	total: 2m 32s	remaining: 1m 41s
# 601:	learn: 0.0781615	total: 2m 32s	remaining: 1m 41s
# 602:	learn: 0.0780338	total: 2m 33s	remaining: 1m 40s
# 603:	learn: 0.0778371	total: 2m 33s	remaining: 1m 40s
# 604:	learn: 0.0775252	total: 2m 33s	remaining: 1m 40s
# 605:	learn: 0.0773525	total: 2m 33s	remaining: 1m 40s
# 606:	learn: 0.0771366	total: 2m 34s	remaining: 1m 39s
# 607:	learn: 0.0769088	total: 2m 34s	remaining: 1m 39s
# 608:	learn: 0.0766739	total: 2m 34s	remaining: 1m 39s
# 609:	learn: 0.0765311	total: 2m 35s	remaining: 1m 39s
# 610:	learn: 0.0763964	total: 2m 35s	remaining: 1m 39s
# 611:	learn: 0.0762480	total: 2m 35s	remaining: 1m 38s
# 612:	learn: 0.0760999	total: 2m 36s	remaining: 1m 38s
# 613:	learn: 0.0759126	total: 2m 37s	remaining: 1m 38s
# 614:	learn: 0.0756849	total: 2m 37s	remaining: 1m 38s
# 615:	learn: 0.0754952	total: 2m 37s	remaining: 1m 38s
# 616:	learn: 0.0752432	total: 2m 37s	remaining: 1m 38s
# 617:	learn: 0.0749953	total: 2m 38s	remaining: 1m 37s
# 618:	learn: 0.0748373	total: 2m 38s	remaining: 1m 37s
# 619:	learn: 0.0747371	total: 2m 38s	remaining: 1m 37s
# 620:	learn: 0.0744803	total: 2m 39s	remaining: 1m 37s
# 621:	learn: 0.0742974	total: 2m 39s	remaining: 1m 36s
# 622:	learn: 0.0741486	total: 2m 39s	remaining: 1m 36s
# 623:	learn: 0.0740082	total: 2m 39s	remaining: 1m 36s
# 624:	learn: 0.0739012	total: 2m 40s	remaining: 1m 36s
# 625:	learn: 0.0736909	total: 2m 40s	remaining: 1m 35s
# 626:	learn: 0.0735050	total: 2m 40s	remaining: 1m 35s
# 627:	learn: 0.0733384	total: 2m 40s	remaining: 1m 35s
# 628:	learn: 0.0730987	total: 2m 40s	remaining: 1m 34s
# 629:	learn: 0.0729878	total: 2m 41s	remaining: 1m 34s
# 630:	learn: 0.0728606	total: 2m 41s	remaining: 1m 34s
# 631:	learn: 0.0727333	total: 2m 41s	remaining: 1m 34s
# 632:	learn: 0.0725708	total: 2m 41s	remaining: 1m 33s
# 633:	learn: 0.0724256	total: 2m 42s	remaining: 1m 33s
# 634:	learn: 0.0721776	total: 2m 42s	remaining: 1m 33s
# 635:	learn: 0.0720543	total: 2m 42s	remaining: 1m 33s
# 636:	learn: 0.0718943	total: 2m 42s	remaining: 1m 32s
# 637:	learn: 0.0717925	total: 2m 43s	remaining: 1m 32s
# 638:	learn: 0.0716267	total: 2m 43s	remaining: 1m 32s
# 639:	learn: 0.0714282	total: 2m 43s	remaining: 1m 32s
# 640:	learn: 0.0712517	total: 2m 44s	remaining: 1m 31s
# 641:	learn: 0.0711067	total: 2m 44s	remaining: 1m 31s
# 642:	learn: 0.0709434	total: 2m 44s	remaining: 1m 31s
# 643:	learn: 0.0707534	total: 2m 44s	remaining: 1m 31s
# 644:	learn: 0.0706196	total: 2m 45s	remaining: 1m 30s
# 645:	learn: 0.0704501	total: 2m 45s	remaining: 1m 30s
# 646:	learn: 0.0703250	total: 2m 45s	remaining: 1m 30s
# 647:	learn: 0.0701994	total: 2m 45s	remaining: 1m 29s
# 648:	learn: 0.0700504	total: 2m 45s	remaining: 1m 29s
# 649:	learn: 0.0699257	total: 2m 46s	remaining: 1m 29s
# 650:	learn: 0.0697746	total: 2m 46s	remaining: 1m 29s
# 651:	learn: 0.0696115	total: 2m 46s	remaining: 1m 28s
# 652:	learn: 0.0694524	total: 2m 46s	remaining: 1m 28s
# 653:	learn: 0.0693312	total: 2m 46s	remaining: 1m 28s
# 654:	learn: 0.0691666	total: 2m 47s	remaining: 1m 28s
# 655:	learn: 0.0690038	total: 2m 47s	remaining: 1m 27s
# 656:	learn: 0.0688315	total: 2m 47s	remaining: 1m 27s
# 657:	learn: 0.0686654	total: 2m 47s	remaining: 1m 27s
# 658:	learn: 0.0685270	total: 2m 48s	remaining: 1m 26s
# 659:	learn: 0.0683868	total: 2m 48s	remaining: 1m 26s
# 660:	learn: 0.0682795	total: 2m 48s	remaining: 1m 26s
# 661:	learn: 0.0681375	total: 2m 48s	remaining: 1m 26s
# 662:	learn: 0.0680110	total: 2m 48s	remaining: 1m 25s
# 663:	learn: 0.0678032	total: 2m 49s	remaining: 1m 25s
# 664:	learn: 0.0676287	total: 2m 49s	remaining: 1m 25s
# 665:	learn: 0.0674910	total: 2m 49s	remaining: 1m 25s
# 666:	learn: 0.0672881	total: 2m 49s	remaining: 1m 24s
# 667:	learn: 0.0671190	total: 2m 49s	remaining: 1m 24s
# 668:	learn: 0.0669679	total: 2m 50s	remaining: 1m 24s
# 669:	learn: 0.0668316	total: 2m 50s	remaining: 1m 23s
# 670:	learn: 0.0667032	total: 2m 50s	remaining: 1m 23s
# 671:	learn: 0.0664728	total: 2m 50s	remaining: 1m 23s
# 672:	learn: 0.0662901	total: 2m 51s	remaining: 1m 23s
# 673:	learn: 0.0661092	total: 2m 51s	remaining: 1m 22s
# 674:	learn: 0.0660160	total: 2m 51s	remaining: 1m 22s
# 675:	learn: 0.0658309	total: 2m 51s	remaining: 1m 22s
# 676:	learn: 0.0656607	total: 2m 51s	remaining: 1m 22s
# 677:	learn: 0.0655436	total: 2m 52s	remaining: 1m 21s
# 678:	learn: 0.0653555	total: 2m 52s	remaining: 1m 21s
# 679:	learn: 0.0652111	total: 2m 52s	remaining: 1m 21s
# 680:	learn: 0.0650991	total: 2m 52s	remaining: 1m 20s
# 681:	learn: 0.0649378	total: 2m 53s	remaining: 1m 20s
# 682:	learn: 0.0648410	total: 2m 53s	remaining: 1m 20s
# 683:	learn: 0.0647164	total: 2m 53s	remaining: 1m 20s
# 684:	learn: 0.0645988	total: 2m 53s	remaining: 1m 19s
# 685:	learn: 0.0645169	total: 2m 53s	remaining: 1m 19s
# 686:	learn: 0.0644287	total: 2m 54s	remaining: 1m 19s
# 687:	learn: 0.0642506	total: 2m 54s	remaining: 1m 19s
# 688:	learn: 0.0640730	total: 2m 54s	remaining: 1m 18s
# 689:	learn: 0.0639646	total: 2m 54s	remaining: 1m 18s
# 690:	learn: 0.0638714	total: 2m 55s	remaining: 1m 18s
# 691:	learn: 0.0637284	total: 2m 55s	remaining: 1m 18s
# 692:	learn: 0.0636050	total: 2m 55s	remaining: 1m 17s
# 693:	learn: 0.0634591	total: 2m 55s	remaining: 1m 17s
# 694:	learn: 0.0633777	total: 2m 56s	remaining: 1m 17s
# 695:	learn: 0.0632529	total: 2m 56s	remaining: 1m 17s
# 696:	learn: 0.0630895	total: 2m 56s	remaining: 1m 16s
# 697:	learn: 0.0629911	total: 2m 56s	remaining: 1m 16s
# 698:	learn: 0.0628516	total: 2m 57s	remaining: 1m 16s
# 699:	learn: 0.0626665	total: 2m 57s	remaining: 1m 16s
# 700:	learn: 0.0625577	total: 2m 58s	remaining: 1m 15s
# 701:	learn: 0.0623756	total: 2m 58s	remaining: 1m 15s
# 702:	learn: 0.0622540	total: 2m 58s	remaining: 1m 15s
# 703:	learn: 0.0621103	total: 2m 59s	remaining: 1m 15s
# 704:	learn: 0.0619736	total: 2m 59s	remaining: 1m 15s
# 705:	learn: 0.0618808	total: 2m 59s	remaining: 1m 14s
# 706:	learn: 0.0616608	total: 2m 59s	remaining: 1m 14s
# 707:	learn: 0.0615448	total: 3m	remaining: 1m 14s
# 708:	learn: 0.0614044	total: 3m	remaining: 1m 14s
# 709:	learn: 0.0612888	total: 3m	remaining: 1m 13s
# 710:	learn: 0.0611075	total: 3m	remaining: 1m 13s
# 711:	learn: 0.0610335	total: 3m	remaining: 1m 13s
# 712:	learn: 0.0609023	total: 3m 1s	remaining: 1m 12s
# 713:	learn: 0.0608119	total: 3m 1s	remaining: 1m 12s
# 714:	learn: 0.0606795	total: 3m 1s	remaining: 1m 12s
# 715:	learn: 0.0605855	total: 3m 2s	remaining: 1m 12s
# 716:	learn: 0.0604815	total: 3m 2s	remaining: 1m 12s
# 717:	learn: 0.0603680	total: 3m 3s	remaining: 1m 11s
# 718:	learn: 0.0602690	total: 3m 3s	remaining: 1m 11s
# 719:	learn: 0.0601265	total: 3m 3s	remaining: 1m 11s
# 720:	learn: 0.0600115	total: 3m 4s	remaining: 1m 11s
# 721:	learn: 0.0598858	total: 3m 4s	remaining: 1m 11s
# 722:	learn: 0.0597657	total: 3m 5s	remaining: 1m 10s
# 723:	learn: 0.0596764	total: 3m 5s	remaining: 1m 10s
# 724:	learn: 0.0595434	total: 3m 5s	remaining: 1m 10s
# 725:	learn: 0.0594444	total: 3m 5s	remaining: 1m 10s
# 726:	learn: 0.0593154	total: 3m 6s	remaining: 1m 9s
# 727:	learn: 0.0592135	total: 3m 6s	remaining: 1m 9s
# 728:	learn: 0.0590430	total: 3m 6s	remaining: 1m 9s
# 729:	learn: 0.0589452	total: 3m 7s	remaining: 1m 9s
# 730:	learn: 0.0588422	total: 3m 7s	remaining: 1m 8s
# 731:	learn: 0.0586871	total: 3m 7s	remaining: 1m 8s
# 732:	learn: 0.0585523	total: 3m 8s	remaining: 1m 8s
# 733:	learn: 0.0584686	total: 3m 8s	remaining: 1m 8s
# 734:	learn: 0.0583831	total: 3m 9s	remaining: 1m 8s
# 735:	learn: 0.0581964	total: 3m 9s	remaining: 1m 7s
# 736:	learn: 0.0580922	total: 3m 9s	remaining: 1m 7s
# 737:	learn: 0.0579635	total: 3m 10s	remaining: 1m 7s
# 738:	learn: 0.0578703	total: 3m 10s	remaining: 1m 7s
# 739:	learn: 0.0576961	total: 3m 10s	remaining: 1m 7s
# 740:	learn: 0.0576131	total: 3m 11s	remaining: 1m 6s
# 741:	learn: 0.0575062	total: 3m 11s	remaining: 1m 6s
# 742:	learn: 0.0573912	total: 3m 11s	remaining: 1m 6s
# 743:	learn: 0.0572826	total: 3m 12s	remaining: 1m 6s
# 744:	learn: 0.0571613	total: 3m 12s	remaining: 1m 5s
# 745:	learn: 0.0570270	total: 3m 13s	remaining: 1m 5s
# 746:	learn: 0.0568617	total: 3m 13s	remaining: 1m 5s
# 747:	learn: 0.0567686	total: 3m 13s	remaining: 1m 5s
# 748:	learn: 0.0566369	total: 3m 14s	remaining: 1m 5s
# 749:	learn: 0.0565023	total: 3m 14s	remaining: 1m 4s
# 750:	learn: 0.0563682	total: 3m 15s	remaining: 1m 4s
# 751:	learn: 0.0562346	total: 3m 15s	remaining: 1m 4s
# 752:	learn: 0.0561387	total: 3m 16s	remaining: 1m 4s
# 753:	learn: 0.0560582	total: 3m 16s	remaining: 1m 4s
# 754:	learn: 0.0559838	total: 3m 16s	remaining: 1m 3s
# 755:	learn: 0.0558958	total: 3m 17s	remaining: 1m 3s
# 756:	learn: 0.0557824	total: 3m 17s	remaining: 1m 3s
# 757:	learn: 0.0556467	total: 3m 17s	remaining: 1m 3s
# 758:	learn: 0.0554945	total: 3m 18s	remaining: 1m 2s
# 759:	learn: 0.0554088	total: 3m 18s	remaining: 1m 2s
# 760:	learn: 0.0552998	total: 3m 18s	remaining: 1m 2s
# 761:	learn: 0.0552119	total: 3m 19s	remaining: 1m 2s
# 762:	learn: 0.0551439	total: 3m 19s	remaining: 1m 1s
# 763:	learn: 0.0550462	total: 3m 19s	remaining: 1m 1s
# 764:	learn: 0.0549420	total: 3m 20s	remaining: 1m 1s
# 765:	learn: 0.0548201	total: 3m 21s	remaining: 1m 1s
# 766:	learn: 0.0546497	total: 3m 21s	remaining: 1m 1s
# 767:	learn: 0.0545346	total: 3m 22s	remaining: 1m 1s
# 768:	learn: 0.0544171	total: 3m 22s	remaining: 1m
# 769:	learn: 0.0542848	total: 3m 22s	remaining: 1m
# 770:	learn: 0.0541542	total: 3m 23s	remaining: 1m
# 771:	learn: 0.0540729	total: 3m 23s	remaining: 1m
# 772:	learn: 0.0540078	total: 3m 23s	remaining: 59.9s
# 773:	learn: 0.0538506	total: 3m 24s	remaining: 59.6s
# 774:	learn: 0.0537438	total: 3m 24s	remaining: 59.4s
# 775:	learn: 0.0536743	total: 3m 25s	remaining: 59.2s
# 776:	learn: 0.0535673	total: 3m 25s	remaining: 58.9s
# 777:	learn: 0.0534557	total: 3m 25s	remaining: 58.7s
# 778:	learn: 0.0533554	total: 3m 26s	remaining: 58.5s
# 779:	learn: 0.0532533	total: 3m 26s	remaining: 58.2s
# 780:	learn: 0.0531601	total: 3m 26s	remaining: 58s
# 781:	learn: 0.0530765	total: 3m 27s	remaining: 57.7s
# 782:	learn: 0.0529884	total: 3m 27s	remaining: 57.5s
# 783:	learn: 0.0528882	total: 3m 27s	remaining: 57.2s
# 784:	learn: 0.0528159	total: 3m 28s	remaining: 57s
# 785:	learn: 0.0527434	total: 3m 28s	remaining: 56.7s
# 786:	learn: 0.0526176	total: 3m 28s	remaining: 56.4s
# 787:	learn: 0.0525451	total: 3m 28s	remaining: 56.2s
# 788:	learn: 0.0524994	total: 3m 29s	remaining: 56s
# 789:	learn: 0.0524168	total: 3m 29s	remaining: 55.7s
# 790:	learn: 0.0523322	total: 3m 29s	remaining: 55.5s
# 791:	learn: 0.0522548	total: 3m 30s	remaining: 55.3s
# 792:	learn: 0.0521725	total: 3m 30s	remaining: 55s
# 793:	learn: 0.0520947	total: 3m 31s	remaining: 54.8s
# 794:	learn: 0.0519979	total: 3m 31s	remaining: 54.6s
# 795:	learn: 0.0519376	total: 3m 31s	remaining: 54.3s
# 796:	learn: 0.0518584	total: 3m 32s	remaining: 54.1s
# 797:	learn: 0.0517613	total: 3m 32s	remaining: 53.8s
# 798:	learn: 0.0516715	total: 3m 33s	remaining: 53.6s
# 799:	learn: 0.0515485	total: 3m 33s	remaining: 53.4s
# 800:	learn: 0.0514680	total: 3m 34s	remaining: 53.2s
# 801:	learn: 0.0513693	total: 3m 34s	remaining: 53s
# 802:	learn: 0.0512746	total: 3m 34s	remaining: 52.7s
# 803:	learn: 0.0511823	total: 3m 35s	remaining: 52.5s
# 804:	learn: 0.0511098	total: 3m 35s	remaining: 52.3s
# 805:	learn: 0.0510603	total: 3m 35s	remaining: 52s
# 806:	learn: 0.0509884	total: 3m 36s	remaining: 51.7s
# 807:	learn: 0.0508789	total: 3m 36s	remaining: 51.5s
# 808:	learn: 0.0507791	total: 3m 36s	remaining: 51.2s
# 809:	learn: 0.0507220	total: 3m 37s	remaining: 51s
# 810:	learn: 0.0506460	total: 3m 37s	remaining: 50.7s
# 811:	learn: 0.0505572	total: 3m 38s	remaining: 50.5s
# 812:	learn: 0.0504681	total: 3m 38s	remaining: 50.3s
# 813:	learn: 0.0503632	total: 3m 39s	remaining: 50.1s
# 814:	learn: 0.0502594	total: 3m 39s	remaining: 49.9s
# 815:	learn: 0.0501668	total: 3m 40s	remaining: 49.6s
# 816:	learn: 0.0500708	total: 3m 40s	remaining: 49.4s
# 817:	learn: 0.0499685	total: 3m 40s	remaining: 49.1s
# 818:	learn: 0.0498972	total: 3m 41s	remaining: 48.9s
# 819:	learn: 0.0497919	total: 3m 41s	remaining: 48.7s
# 820:	learn: 0.0496801	total: 3m 42s	remaining: 48.4s
# 821:	learn: 0.0496145	total: 3m 42s	remaining: 48.1s
# 822:	learn: 0.0495173	total: 3m 42s	remaining: 47.9s
# 823:	learn: 0.0494602	total: 3m 43s	remaining: 47.6s
# 824:	learn: 0.0493786	total: 3m 43s	remaining: 47.4s
# 825:	learn: 0.0492958	total: 3m 44s	remaining: 47.2s
# 826:	learn: 0.0492302	total: 3m 44s	remaining: 47s
# 827:	learn: 0.0491294	total: 3m 44s	remaining: 46.7s
# 828:	learn: 0.0490546	total: 3m 45s	remaining: 46.5s
# 829:	learn: 0.0489654	total: 3m 45s	remaining: 46.2s
# 830:	learn: 0.0488950	total: 3m 45s	remaining: 45.9s
# 831:	learn: 0.0488203	total: 3m 46s	remaining: 45.7s
# 832:	learn: 0.0487407	total: 3m 46s	remaining: 45.4s
# 833:	learn: 0.0486840	total: 3m 46s	remaining: 45.1s
# 834:	learn: 0.0485993	total: 3m 47s	remaining: 44.9s
# 835:	learn: 0.0485085	total: 3m 47s	remaining: 44.6s
# 836:	learn: 0.0484716	total: 3m 47s	remaining: 44.4s
# 837:	learn: 0.0483858	total: 3m 48s	remaining: 44.1s
# 838:	learn: 0.0483466	total: 3m 48s	remaining: 43.8s
# 839:	learn: 0.0482351	total: 3m 48s	remaining: 43.6s
# 840:	learn: 0.0481807	total: 3m 48s	remaining: 43.3s
# 841:	learn: 0.0481067	total: 3m 49s	remaining: 43s
# 842:	learn: 0.0479889	total: 3m 49s	remaining: 42.7s
# 843:	learn: 0.0479240	total: 3m 49s	remaining: 42.5s
# 844:	learn: 0.0478389	total: 3m 50s	remaining: 42.2s
# 845:	learn: 0.0477575	total: 3m 50s	remaining: 42s
# 846:	learn: 0.0476601	total: 3m 51s	remaining: 41.7s
# 847:	learn: 0.0476069	total: 3m 51s	remaining: 41.5s
# 848:	learn: 0.0475351	total: 3m 51s	remaining: 41.2s
# 849:	learn: 0.0474735	total: 3m 51s	remaining: 40.9s
# 850:	learn: 0.0473782	total: 3m 52s	remaining: 40.6s
# 851:	learn: 0.0472599	total: 3m 52s	remaining: 40.4s
# 852:	learn: 0.0471633	total: 3m 52s	remaining: 40.1s
# 853:	learn: 0.0470924	total: 3m 52s	remaining: 39.8s
# 854:	learn: 0.0470034	total: 3m 53s	remaining: 39.5s
# 855:	learn: 0.0469319	total: 3m 53s	remaining: 39.3s
# 856:	learn: 0.0468072	total: 3m 53s	remaining: 39s
# 857:	learn: 0.0467230	total: 3m 54s	remaining: 38.7s
# 858:	learn: 0.0466299	total: 3m 54s	remaining: 38.5s
# 859:	learn: 0.0465753	total: 3m 54s	remaining: 38.2s
# 860:	learn: 0.0464834	total: 3m 55s	remaining: 38s
# 861:	learn: 0.0463761	total: 3m 55s	remaining: 37.7s
# 862:	learn: 0.0462868	total: 3m 55s	remaining: 37.5s
# 863:	learn: 0.0461961	total: 3m 56s	remaining: 37.2s
# 864:	learn: 0.0461317	total: 3m 56s	remaining: 36.9s
# 865:	learn: 0.0460127	total: 3m 56s	remaining: 36.6s
# 866:	learn: 0.0459424	total: 3m 57s	remaining: 36.4s
# 867:	learn: 0.0458770	total: 3m 57s	remaining: 36.1s
# 868:	learn: 0.0457648	total: 3m 57s	remaining: 35.8s
# 869:	learn: 0.0456714	total: 3m 58s	remaining: 35.6s
# 870:	learn: 0.0456203	total: 3m 58s	remaining: 35.3s
# 871:	learn: 0.0455437	total: 3m 59s	remaining: 35.1s
# 872:	learn: 0.0454600	total: 3m 59s	remaining: 34.8s
# 873:	learn: 0.0453561	total: 3m 59s	remaining: 34.5s
# 874:	learn: 0.0452977	total: 3m 59s	remaining: 34.3s
# 875:	learn: 0.0452402	total: 4m	remaining: 34s
# 876:	learn: 0.0451790	total: 4m	remaining: 33.7s
# 877:	learn: 0.0450859	total: 4m	remaining: 33.4s
# 878:	learn: 0.0450416	total: 4m	remaining: 33.2s
# 879:	learn: 0.0449508	total: 4m 1s	remaining: 32.9s
# 880:	learn: 0.0448845	total: 4m 1s	remaining: 32.7s
# 881:	learn: 0.0448177	total: 4m 2s	remaining: 32.4s
# 882:	learn: 0.0447403	total: 4m 2s	remaining: 32.1s
# 883:	learn: 0.0446617	total: 4m 3s	remaining: 31.9s
# 884:	learn: 0.0445900	total: 4m 3s	remaining: 31.6s
# 885:	learn: 0.0445019	total: 4m 3s	remaining: 31.4s
# 886:	learn: 0.0444106	total: 4m 4s	remaining: 31.1s
# 887:	learn: 0.0443434	total: 4m 4s	remaining: 30.8s
# 888:	learn: 0.0442760	total: 4m 4s	remaining: 30.6s
# 889:	learn: 0.0441731	total: 4m 5s	remaining: 30.3s
# 890:	learn: 0.0441299	total: 4m 5s	remaining: 30s
# 891:	learn: 0.0440540	total: 4m 5s	remaining: 29.8s
# 892:	learn: 0.0439798	total: 4m 6s	remaining: 29.5s
# 893:	learn: 0.0439289	total: 4m 6s	remaining: 29.2s
# 894:	learn: 0.0438571	total: 4m 6s	remaining: 29s
# 895:	learn: 0.0437684	total: 4m 7s	remaining: 28.7s
# 896:	learn: 0.0437241	total: 4m 7s	remaining: 28.4s
# 897:	learn: 0.0436454	total: 4m 7s	remaining: 28.2s
# 898:	learn: 0.0435816	total: 4m 8s	remaining: 27.9s
# 899:	learn: 0.0435066	total: 4m 8s	remaining: 27.6s
# 900:	learn: 0.0434530	total: 4m 9s	remaining: 27.4s
# 901:	learn: 0.0433752	total: 4m 9s	remaining: 27.1s
# 902:	learn: 0.0432803	total: 4m 10s	remaining: 26.9s
# 903:	learn: 0.0432078	total: 4m 10s	remaining: 26.6s
# 904:	learn: 0.0431288	total: 4m 10s	remaining: 26.3s
# 905:	learn: 0.0430230	total: 4m 11s	remaining: 26.1s
# 906:	learn: 0.0429413	total: 4m 11s	remaining: 25.8s
# 907:	learn: 0.0428913	total: 4m 11s	remaining: 25.5s
# 908:	learn: 0.0428187	total: 4m 12s	remaining: 25.2s
# 909:	learn: 0.0427234	total: 4m 12s	remaining: 24.9s
# 910:	learn: 0.0426365	total: 4m 12s	remaining: 24.7s
# 911:	learn: 0.0425809	total: 4m 12s	remaining: 24.4s
# 912:	learn: 0.0425082	total: 4m 13s	remaining: 24.1s
# 913:	learn: 0.0424385	total: 4m 13s	remaining: 23.8s
# 914:	learn: 0.0423778	total: 4m 13s	remaining: 23.6s
# 915:	learn: 0.0423296	total: 4m 13s	remaining: 23.3s
# 916:	learn: 0.0422611	total: 4m 14s	remaining: 23s
# 917:	learn: 0.0422229	total: 4m 14s	remaining: 22.7s
# 918:	learn: 0.0421449	total: 4m 14s	remaining: 22.5s
# 919:	learn: 0.0420943	total: 4m 15s	remaining: 22.2s
# 920:	learn: 0.0420258	total: 4m 15s	remaining: 21.9s
# 921:	learn: 0.0419818	total: 4m 15s	remaining: 21.6s
# 922:	learn: 0.0419088	total: 4m 16s	remaining: 21.4s
# 923:	learn: 0.0418258	total: 4m 16s	remaining: 21.1s
# 924:	learn: 0.0418013	total: 4m 16s	remaining: 20.8s
# 925:	learn: 0.0417681	total: 4m 16s	remaining: 20.5s
# 926:	learn: 0.0416771	total: 4m 17s	remaining: 20.3s
# 927:	learn: 0.0416055	total: 4m 17s	remaining: 20s
# 928:	learn: 0.0415647	total: 4m 17s	remaining: 19.7s
# 929:	learn: 0.0414597	total: 4m 18s	remaining: 19.4s
# 930:	learn: 0.0413977	total: 4m 18s	remaining: 19.2s
# 931:	learn: 0.0413370	total: 4m 18s	remaining: 18.9s
# 932:	learn: 0.0412796	total: 4m 19s	remaining: 18.6s
# 933:	learn: 0.0412297	total: 4m 19s	remaining: 18.3s
# 934:	learn: 0.0411854	total: 4m 19s	remaining: 18s
# 935:	learn: 0.0411267	total: 4m 19s	remaining: 17.8s
# 936:	learn: 0.0410777	total: 4m 20s	remaining: 17.5s
# 937:	learn: 0.0410254	total: 4m 20s	remaining: 17.2s
# 938:	learn: 0.0409551	total: 4m 20s	remaining: 17s
# 939:	learn: 0.0409208	total: 4m 21s	remaining: 16.7s
# 940:	learn: 0.0408700	total: 4m 21s	remaining: 16.4s
# 941:	learn: 0.0408095	total: 4m 22s	remaining: 16.1s
# 942:	learn: 0.0407595	total: 4m 22s	remaining: 15.9s
# 943:	learn: 0.0406895	total: 4m 22s	remaining: 15.6s
# 944:	learn: 0.0405921	total: 4m 22s	remaining: 15.3s
# 945:	learn: 0.0405355	total: 4m 23s	remaining: 15s
# 946:	learn: 0.0404617	total: 4m 23s	remaining: 14.8s
# 947:	learn: 0.0404171	total: 4m 23s	remaining: 14.5s
# 948:	learn: 0.0403434	total: 4m 24s	remaining: 14.2s
# 949:	learn: 0.0402625	total: 4m 24s	remaining: 13.9s
# 950:	learn: 0.0402013	total: 4m 24s	remaining: 13.6s
# 951:	learn: 0.0401334	total: 4m 25s	remaining: 13.4s
# 952:	learn: 0.0400570	total: 4m 25s	remaining: 13.1s
# 953:	learn: 0.0399730	total: 4m 25s	remaining: 12.8s
# 954:	learn: 0.0399264	total: 4m 26s	remaining: 12.5s
# 955:	learn: 0.0398787	total: 4m 26s	remaining: 12.3s
# 956:	learn: 0.0398270	total: 4m 26s	remaining: 12s
# 957:	learn: 0.0397665	total: 4m 26s	remaining: 11.7s
# 958:	learn: 0.0397050	total: 4m 27s	remaining: 11.4s
# 959:	learn: 0.0396479	total: 4m 27s	remaining: 11.1s
# 960:	learn: 0.0395740	total: 4m 27s	remaining: 10.9s
# 961:	learn: 0.0395192	total: 4m 27s	remaining: 10.6s
# 962:	learn: 0.0394497	total: 4m 28s	remaining: 10.3s
# 963:	learn: 0.0394087	total: 4m 28s	remaining: 10s
# 964:	learn: 0.0393801	total: 4m 28s	remaining: 9.74s
# 965:	learn: 0.0393007	total: 4m 28s	remaining: 9.46s
# 966:	learn: 0.0392526	total: 4m 29s	remaining: 9.19s
# 967:	learn: 0.0391980	total: 4m 29s	remaining: 8.91s
# 968:	learn: 0.0391246	total: 4m 29s	remaining: 8.63s
# 969:	learn: 0.0390738	total: 4m 30s	remaining: 8.35s
# 970:	learn: 0.0390216	total: 4m 30s	remaining: 8.07s
# 971:	learn: 0.0389633	total: 4m 30s	remaining: 7.8s
# 972:	learn: 0.0389176	total: 4m 30s	remaining: 7.52s
# 973:	learn: 0.0388609	total: 4m 31s	remaining: 7.24s
# 974:	learn: 0.0388271	total: 4m 31s	remaining: 6.96s
# 975:	learn: 0.0387972	total: 4m 31s	remaining: 6.68s
# 976:	learn: 0.0387027	total: 4m 32s	remaining: 6.4s
# 977:	learn: 0.0386397	total: 4m 32s	remaining: 6.13s
# 978:	learn: 0.0385926	total: 4m 32s	remaining: 5.85s
# 979:	learn: 0.0385466	total: 4m 32s	remaining: 5.57s
# 980:	learn: 0.0384696	total: 4m 33s	remaining: 5.29s
# 981:	learn: 0.0384098	total: 4m 33s	remaining: 5.02s
# 982:	learn: 0.0383465	total: 4m 34s	remaining: 4.75s
# 983:	learn: 0.0382976	total: 4m 34s	remaining: 4.47s
# 984:	learn: 0.0382563	total: 4m 35s	remaining: 4.19s
# 985:	learn: 0.0381775	total: 4m 35s	remaining: 3.91s
# 986:	learn: 0.0380899	total: 4m 35s	remaining: 3.63s
# 987:	learn: 0.0380363	total: 4m 36s	remaining: 3.35s
# 988:	learn: 0.0379811	total: 4m 36s	remaining: 3.08s
# 989:	learn: 0.0379346	total: 4m 37s	remaining: 2.8s
# 990:	learn: 0.0378802	total: 4m 38s	remaining: 2.52s
# 991:	learn: 0.0378188	total: 4m 38s	remaining: 2.25s
# 992:	learn: 0.0377793	total: 4m 38s	remaining: 1.97s
# 993:	learn: 0.0377154	total: 4m 39s	remaining: 1.69s
# 994:	learn: 0.0376646	total: 4m 39s	remaining: 1.41s
# 995:	learn: 0.0376212	total: 4m 40s	remaining: 1.13s
# 996:	learn: 0.0375612	total: 4m 40s	remaining: 845ms
# 997:	learn: 0.0375096	total: 4m 41s	remaining: 563ms
# 998:	learn: 0.0374411	total: 4m 41s	remaining: 282ms
# 999:	learn: 0.0373693	total: 4m 41s	remaining: 0us
# CatBoost - Best F1 Score: 0.7407316817206515
# Evaluating RandomForest...
# Fitting 10 folds for each of 20 candidates, totalling 200 fits
# RandomForest - Best F1 Score: 0.7420054200542006
# Evaluating TabNet...
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# C:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\pytorch_tabnet\abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")
# Fitting 10 folds for each of 20 candidates, totalling 200 fits

# %%
import pathlib

# Define the root path to the "telangana-crop-health-challenge" directory in Downloads
root_path = pathlib.Path('C:/Users/USER/Downloads/telangana-crop-health-challenge')

# Load submission file
sample_submission = pd.read_csv(root_path / "SampleSubmission.csv")

# Predict on the test set
test_predictions = random_search.best_estimator_.predict(test_encoded.drop(columns=['target']))  # Drop 'FarmID' if it exists in test_encoded

# Fill sample_submission.csv & Save
sample_submission['Target'] = test_predictions
sample_submission['Target'] = sample_submission['Target'].astype(int).map(idx_to_category_mapper)
sample_submission.to_csv('submission.csv', index=False)

# %%
sample_submission.head(59)

# %%
# # Optional: Feature importance
# feature_importance = best_model.get_feature_importance()
# print("\nFeature Importances:")
# for feature, importance in zip(X.columns, feature_importance):
#     print(f"{feature}: {importance:.4f}")
